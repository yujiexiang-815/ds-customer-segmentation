# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.exc import SQLAlchemyError # 引入异常处理
from urllib.parse import quote_plus


DB_HOST = 'rm-bp1o6283vw74wr4x5.mysql.rds.aliyuncs.com'    
DB_PORT = 3306
DB_USER = 'on_ds_test' 
DB_PASS = quote_plus('HC73aA7aeLxJFLFH_@bPeHkv')
DB_NAME = 'on_ds_test'

# 构建 SQLAlchemy 连接字符串：dialect+driver://user:pass@host:port/database?charset
DATABASE_URL = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}?charset=utf8mb4"

try:
    # 创建数据库引擎
    engine = create_engine(DATABASE_URL)
    print("✅ 数据库连接引擎创建成功。")
except Exception as e:
    print(f"❌ 数据库连接失败: {e}")
    # 失败则退出程序，避免后续代码报错
    sys.exit()
# Out:
# ✅ 数据库连接引擎创建成功。

# %%
# read & process order table, exclude member_uid = None
ORDER_MYSQL = 'dwd_dtc_store_sales_order_detail'

try:
    order = pd.read_sql(f'SELECT * FROM {ORDER_MYSQL} WHERE member_uid != "" ', con=engine)
    
    print(f"\n✅ 成功加载表 '{ORDER_MYSQL}'，共 {len(order)} 行。")
    print("\nDataFrame 头部数据:")
    display(order.head()) # 在 Jupyter Notebook 中，使用 display(df.head()) 比 print(df.head()) 效果更好

except Exception as e:
    print(f"❌ 加载表时出错: {e}")
    
# order = order[order['member_uid']!='']
# Out:
# ✅ 成功加载表 'dwd_dtc_store_sales_order_detail'，共 2375790 行。
#
# DataFrame 头部数据:
#           id   channel        order_number    status order_type  \
# 0  2990598.0  DTC-ECOM  146948246587692845  complete   exchange
# 1  2940619.0  DTC-ECOM  211515639677977589  complete   exchange
# 2  2990601.0  DTC-ECOM  211834851936739809  complete   exchange
# 3  2990201.0  DTC-ECOM  211853209416818620  complete   exchange
# 4  2990730.0  DTC-ECOM  211858214117548471  complete   exchange
#
#   original_order_number        date store_code  \
# 0                  None  2025-05-11       DY01
# 1                  None  2025-05-08       TM01
# 2                  None  2025-05-11       TM01
# 3                  None  2025-05-11       TM01
# 4                  None  2025-05-11       TM01
#
#                                           member_uid coupon_code  ...  \
# 0  1@#4E8PmyxwPguiI+bfGKis1PBi++lFFh9ezWaML/VTNEG...        None  ...
# 1                           AAHPAaPlAAAF_e4AAUhPqZSD        None  ...
# 2                           AAEnAaPlAAAF_e4AAUhHcldX        None  ...
# 3                           AAE6AaPlAAAF_e4AAUhuISFK        None  ...
# 4                           AAGPAaPlAAAF_e4AAUjTt0SB        None  ...
#
#   BR Revenue BR Order BR Item  Return Revenue Return Item  Return Order  \
# 0        0.0     None       0         -1190.0          -1          None
# 1        0.0     None       0         -1190.0          -1          None
# 2        0.0     None       0          -460.0          -1          None
# 3        0.0     None       0         -1490.0          -1          None
# 4        0.0     None       0         -1090.0          -1          None
#
#    AR Revenue  AR Item  balance_paid_amount  is_tax_refund
# 0      1190.0        1                  0.0              0
# 1      1190.0        1                  0.0              0
# 2       460.0        1                  0.0              0
# 3      1490.0        1                  0.0              0
# 4      1090.0        1                  0.0              0
#
# [5 rows x 36 columns]

# %%
# read & process member table
MEMBER_MYSQL = 'dwd_crm_members'
try:
    member = pd.read_sql_table(
        table_name=MEMBER_MYSQL, 
        con=engine
    )
    
    
    print(f"\n✅ 成功加载表 '{MEMBER_MYSQL}'，共 {len(member)} 行。")
    print("\nDataFrame 头部数据:")
    display(member.head()) # 在 Jupyter Notebook 中，使用 display(df.head()) 比 print(df.head()) 效果更好

except Exception as e:
    print(f"❌ 加载表时出错: {e}")
# Out:
# ✅ 成功加载表 'dwd_crm_members'，共 1066346 行。
#
# DataFrame 头部数据:
#           id   channel        order_number    status order_type  \
# 0  2990598.0  DTC-ECOM  146948246587692845  complete   exchange
# 1  2940619.0  DTC-ECOM  211515639677977589  complete   exchange
# 2  2990601.0  DTC-ECOM  211834851936739809  complete   exchange
# 3  2990201.0  DTC-ECOM  211853209416818620  complete   exchange
# 4  2990730.0  DTC-ECOM  211858214117548471  complete   exchange
#
#   original_order_number        date store_code  \
# 0                  None  2025-05-11       DY01
# 1                  None  2025-05-08       TM01
# 2                  None  2025-05-11       TM01
# 3                  None  2025-05-11       TM01
# 4                  None  2025-05-11       TM01
#
#                                           member_uid coupon_code  ...  \
# 0  1@#4E8PmyxwPguiI+bfGKis1PBi++lFFh9ezWaML/VTNEG...        None  ...
# 1                           AAHPAaPlAAAF_e4AAUhPqZSD        None  ...
# 2                           AAEnAaPlAAAF_e4AAUhHcldX        None  ...
# 3                           AAE6AaPlAAAF_e4AAUhuISFK        None  ...
# 4                           AAGPAaPlAAAF_e4AAUjTt0SB        None  ...
#
#   BR Revenue BR Order BR Item  Return Revenue Return Item  Return Order  \
# 0        0.0     None       0         -1190.0          -1          None
# 1        0.0     None       0         -1190.0          -1          None
# 2        0.0     None       0          -460.0          -1          None
# 3        0.0     None       0         -1490.0          -1          None
# 4        0.0     None       0         -1090.0          -1          None
#
#    AR Revenue  AR Item  balance_paid_amount  is_tax_refund
# 0      1190.0        1                  0.0              0
# 1      1190.0        1                  0.0              0
# 2       460.0        1                  0.0              0
# 3      1490.0        1                  0.0              0
# 4      1090.0        1                  0.0              0
#
# [5 rows x 36 columns]

# %%
import pandas as pd
from datetime import datetime
import numpy as np

def calculate_rfm_score(orders_df, members_df, customer_id_col, order_date_col, sales_amount_col):
    """
    计算客户的RFM值和总分。
    
    参数:
    orders_df (pd.DataFrame): 订单表。
    members_df (pd.DataFrame): 会员信息表。
    customer_id_col (str): 客户ID列名。
    order_date_col (str): 订单日期列名。
    sales_amount_col (str): 销售金额列名。
    
    返回:
    pd.DataFrame: 包含RFM值和总分的会员信息表。
    """
    
    # 设定快照日期为订单表中最晚日期之后的一天
    snapshot_date = orders_df[order_date_col].max() + pd.Timedelta(days=1)
    
    # a. 计算 R (Recency), F (Frequency), M (Monetary)
#     rfm_df = orders_df.groupby(customer_id_col).agg(
#         Recency=(order_date_col, lambda x: (snapshot_date - x.max()).days), # R: 距今最近一次购买天数 (排除退货)
#         Frequency=(customer_id_col, 'count'),                                 # F: 购买次数 (排除退货)
#         Monetary=(sales_amount_col, 'sum')                                  # M: 总消费金额 (金额越多越好)
#     ).reset_index()
    
    rfm_df = orders_df.groupby(customer_id_col).agg(
    # Recency: 计算所有订单的最大日期  （包括退单）
    Recency=(order_date_col, lambda x: (snapshot_date - x.max()).days), # R: 距今最近一次购买天数 (排除退货)

    # Frequency: 仅计算 'normal' 订单的行数，防止多次退换
    Frequency=(customer_id_col, lambda x: (orders_df.loc[x.index, 'order_type'] == 'normal').sum() 
              ),                                

    # Monetary: 可以使用相似的逻辑来计算 'complete' 订单的金额总和
     Monetary=(sales_amount_col, 'sum')
     ).reset_index()
    

    # b. 自定义分位数打分函数
    # Top 25% (Q4) -> 4分, 50-75% (Q3) -> 3分, 25-50% (Q2) -> 2分, Bottom 25% (Q1) -> 1分
    def quantile_score(series, is_recency=False):
        # 计算四分位数
        # 注意: 如果数据集过小或存在大量相同值，这里的分位数可能无法完美划分 - 此问题已解决，因为订单表已经筛选revenue>0的
        quantiles = series.quantile([0.25, 0.5, 0.75]).to_dict()
        
        score_series = pd.Series(index=series.index, dtype=float)
        
        if is_recency:
            # R (Recency): 值越低越好，分数 [4, 3, 2, 1]
            score_series[series <= quantiles[0.25]] = 4
            score_series[(series > quantiles[0.25]) & (series <= quantiles[0.5])] = 3
            score_series[(series > quantiles[0.5]) & (series <= quantiles[0.75])] = 2
            score_series[series > quantiles[0.75]] = 1
        else:
            # F/M (Frequency/Monetary): 值越高越好，分数 [1, 2, 3, 4]
            score_series[series <= quantiles[0.25]] = 1
            score_series[(series > quantiles[0.25]) & (series <= quantiles[0.5])] = 2
            score_series[(series > quantiles[0.5]) & (series <= quantiles[0.75])] = 3
            score_series[series > quantiles[0.75]] = 4
            
        # 填充可能因数据极端分布导致的空值（这里填充为0，但在实际应用中可以根据业务逻辑调整）
        return score_series.fillna(0)

    rfm_df['R_Score'] = quantile_score(rfm_df['Recency'], is_recency=True)
    rfm_df['F_Score'] = quantile_score(rfm_df['Frequency'])
    rfm_df['M_Score'] = quantile_score(rfm_df['Monetary'])

    # c. 计算总分 (总分为三个分数相加)
    rfm_df['RFM_Total_Score'] = rfm_df['R_Score'] + rfm_df['F_Score'] + rfm_df['M_Score']

    # d. 合并回会员信息表
    final_df = pd.merge(members_df, rfm_df[[customer_id_col, 'Recency','Frequency','Monetary','R_Score', 'F_Score', 'M_Score', 'RFM_Total_Score']], 
                        on=customer_id_col, how='left')
    
    # 对于没有订单的客户，RFM总分填充为 0 分
    final_df[['R_Score', 'F_Score', 'M_Score', 'RFM_Total_Score']] = final_df[['R_Score', 'F_Score', 'M_Score', 'RFM_Total_Score']].fillna(0)
    
    # 输出中间表rfm_df，用来后续分析 & 阈值的选择
    return rfm_df, final_df

# %%
rfm_mid, rfm_data = calculate_rfm_score(order, member, 'member_uid', 'date','AR Revenue')
rfm_data.head()
# Out:
#   member_channel   member_store store_code     store_name  \
# 0   DTC-Mp & Web       Mp & Web       None           None
# 1   DTC-Mp & Web       Mp & Web       None           None
# 2     DTC-RETAIL  On昂跑 深圳益田假日广场      S0017  On昂跑 深圳益田假日广场
# 3   DTC-Mp & Web       Mp & Web       None           None
# 4   DTC-Mp & Web       Mp & Web       None           None
#
#                              member_uid                        member_uid_one  \
# 0  4af0541c-148f-4f5c-a9f3-7e434b7f09f2  4af0541c-148f-4f5c-a9f3-7e434b7f09f2
# 1  9cf1e32c-e4b3-49c1-bd38-fbaf93552a33  9cf1e32c-e4b3-49c1-bd38-fbaf93552a33
# 2  14749aac-e36a-4477-bfa1-fede3b3c3fe4  14749aac-e36a-4477-bfa1-fede3b3c3fe4
# 3  793d6c2d-2230-4e64-8287-176a78e0a8bd  793d6c2d-2230-4e64-8287-176a78e0a8bd
# 4  e69b772c-34c0-49de-80c9-92f4dc256a7c  e69b772c-34c0-49de-80c9-92f4dc256a7c
#
#   is_omni_channel_member  is register dtc register_channel  \
# 0                   true                1        Wechat Mp
# 1                   true                1        Wechat Mp
# 2                   true                1        Wechat Mp
# 3                   true                1        Wechat Mp
# 4                   true                1        Wechat Mp
#
#         register_time  ... employee status  Suspected Scalper Customer  \
# 0 2025-10-20 15:04:02  ...            None                           0
# 1 2024-10-22 00:46:16  ...            None                           0
# 2 2024-01-11 16:21:10  ...            None                           0
# 3 2025-04-01 17:48:55  ...            None                           0
# 4 2024-10-30 15:07:49  ...            None                           0
#
#    member_uid_one_flg Recency Frequency Monetary R_Score F_Score M_Score  \
# 0                   1     NaN       NaN      NaN     0.0     0.0     0.0
# 1                   1     NaN       NaN      NaN     0.0     0.0     0.0
# 2                   1   669.0       2.0   2480.0     1.0     3.0     4.0
# 3                   1    17.0      16.0   1710.0     4.0     4.0     3.0
# 4                   1     NaN       NaN      NaN     0.0     0.0     0.0
#
#   RFM_Total_Score
# 0             0.0
# 1             0.0
# 2             8.0
# 3            11.0
# 4             0.0
#
# [5 rows x 40 columns]

# %%
import matplotlib.pyplot as plt
# 2. Select the numerical columns for RFM analysis (excluding customer_Id)
rfm_cols = ['Recency', 'Frequency', 'Monetary']

# 3. Generate the boxplots
# We create a figure with three subplots for clarity
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('RFM Distribution Boxplots', fontsize=16)

# Loop through the columns and generate a boxplot for each
for i, col in enumerate(rfm_cols):
    # Use pandas boxplot method on the selected column and subplot axis
    rfm_data.boxplot(column=col, ax=axes[i], patch_artist=True)
    
    # Set titles and labels
    axes[i].set_title(col.capitalize(), fontsize=14)
    axes[i].set_ylabel('Value', fontsize=12)
    axes[i].grid(axis='y', linestyle='--')

plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout
plt.style.use('seaborn-v0_8-whitegrid')

# 4. Save the plot
plt.savefig('rfm_boxplots.png')

# %%
# 一些奇怪的人 
# order[order['member_uid']=='b3cb9447-334c-42df-8f1e-8f4f43a2e404'].groupby('store_code').agg(
#         BR_Item=('BR Item', 'sum'),                                 # F: 购买次数 (次数越多越好)
#         BR_Revenue=('BR Revenue', 'sum'),                                  # M: 总消费金额 (金额越多越好)
#         AR_Item=('AR Item', 'sum'),                                 # F: 购买次数 (次数越多越好)
#         AR_Revenue=('AR Revenue', 'sum') 
#     ).reset_index()


# b3cb9447-334c-42df-8f1e-8f4f43a2e404 一个疯狂在静安嘉里购物的人
# 9039690e-5c61-45ee-a2cc-38cce7d6d3ee 一个疯狂在MP退货的人
# Out:
#   store_code  BR_Item  BR_Revenue  AR_Item  AR_Revenue
# 0      S0002     1745   1892304.0     1604   1746848.0
# 1       WXMP       42     18282.0       42     18282.0

# %%
rfm_data[rfm_cols].describe()
# Out:
#              Recency      Frequency      Monetary
# count  415319.000000  415319.000000  4.153190e+05
# mean      269.148288       2.737994  2.443060e+03
# std       237.795770       6.061332  5.080777e+03
# min         1.000000       0.000000 -3.012220e+04
# 25%        91.000000       1.000000  1.190000e+03
# 50%       190.000000       2.000000  1.410000e+03
# 75%       388.000000       3.000000  2.680000e+03
# max      1371.000000    1716.000000  1.765130e+06

# %%
# --- assign cluster ---

def assign_rfm_cluster(df):
    """
    根据预设的条件为客户分配 RFM 集群标签。
    注意: 分类是有优先级的，通常是先处理不活跃/流失客户，再处理高价值客户。
    """
    df['Cluster'] = 'Unclassified'
    
    # 计算 Last Order 至今的月数 (用于 Passive 和 Lost 判定)
    # Recency 是距离 SNAPSHOT_DATE 的天数
    df['Months_Since_Last_Order'] = df['Recency'] / 30.4 # 近似每月天数

    # --- 1. 优先处理 流失/不活跃 客户 (基于时间) ---
    # Lost: Last order >= 36 months
    df.loc[df['Months_Since_Last_Order'] >= 36, 'Cluster'] = '6 - Lost'

    # Passive: Last order >= 30 months (且尚未被归为 Lost 的)
    df.loc[(df['Cluster'] == 'Unclassified') & 
           (df['Months_Since_Last_Order'] >= 30), 'Cluster'] = '5 - Passive'

    # --- 2. 处理 高价值 客户 (基于总分) ---
    # High Value: RFM > 10
    df.loc[df['RFM_Total_Score'] > 10, 'Cluster'] = '1 - High Value'

    # Fans: 9 ≤ RFM ≤ 10
    df.loc[(df['Cluster'] == 'Unclassified') & 
           (df['RFM_Total_Score'] >= 9) & 
           (df['RFM_Total_Score'] <= 10), 'Cluster'] = '2 - Fans'
    
    # --- 3. 处理 新客 (基于 R 和 F/M) ---
    # Newcomers: R = 4 and (F, M) in (1,2)
    # F/M 分数在 1 或 2，表示 F/M 在 Bottom 50%，但 R 很高。
    df.loc[(df['Cluster'] == 'Unclassified') & 
           (df['R_Score'] == 4) & 
           (df['F_Score'].isin([1.0, 2.0])) & 
           (df['M_Score'].isin([1.0, 2.0])), 'Cluster'] = '4 - Newcomers'

    # --- 4. 处理 一般/低价值 客户 (基于剩余总分) ---
    # Aspiring Fans: 6 ≤ RFM ≤ 8
    df.loc[(df['Cluster'] == 'Unclassified') & 
           (df['RFM_Total_Score'] >= 6) & 
           (df['RFM_Total_Score'] <= 8), 'Cluster'] = '3 - Aspiring Fans'

    # Low Value: 3 ≤ RFM ≤ 5
    df.loc[(df['Cluster'] == 'Unclassified') & 
           (df['RFM_Total_Score'] >= 3) & 
           (df['RFM_Total_Score'] <= 5), 'Cluster'] = '7 - Low Value'
    
    # 5. 零值客户 (没有订单的会员)
    df.loc[df['RFM_Total_Score'] == 0, 'Cluster'] = '8 - Zero Value/No Orders'
    
    return df

# 执行分群
rfm_clustered_df = assign_rfm_cluster(rfm_data.copy())

# %%
rfm_clustered_df.head()
# rfm_clustered_df['date'].min()
# Out:
#   member_channel   member_store store_code     store_name  \
# 0   DTC-Mp & Web       Mp & Web       None           None
# 1   DTC-Mp & Web       Mp & Web       None           None
# 2     DTC-RETAIL  On昂跑 深圳益田假日广场      S0017  On昂跑 深圳益田假日广场
# 3   DTC-Mp & Web       Mp & Web       None           None
# 4   DTC-Mp & Web       Mp & Web       None           None
#
#                              member_uid                        member_uid_one  \
# 0  4af0541c-148f-4f5c-a9f3-7e434b7f09f2  4af0541c-148f-4f5c-a9f3-7e434b7f09f2
# 1  9cf1e32c-e4b3-49c1-bd38-fbaf93552a33  9cf1e32c-e4b3-49c1-bd38-fbaf93552a33
# 2  14749aac-e36a-4477-bfa1-fede3b3c3fe4  14749aac-e36a-4477-bfa1-fede3b3c3fe4
# 3  793d6c2d-2230-4e64-8287-176a78e0a8bd  793d6c2d-2230-4e64-8287-176a78e0a8bd
# 4  e69b772c-34c0-49de-80c9-92f4dc256a7c  e69b772c-34c0-49de-80c9-92f4dc256a7c
#
#   is_omni_channel_member  is register dtc register_channel  \
# 0                   true                1        Wechat Mp
# 1                   true                1        Wechat Mp
# 2                   true                1        Wechat Mp
# 3                   true                1        Wechat Mp
# 4                   true                1        Wechat Mp
#
#         register_time  ... member_uid_one_flg  Recency  Frequency Monetary  \
# 0 2025-10-20 15:04:02  ...                  1      NaN        NaN      NaN
# 1 2024-10-22 00:46:16  ...                  1      NaN        NaN      NaN
# 2 2024-01-11 16:21:10  ...                  1    669.0        2.0   2480.0
# 3 2025-04-01 17:48:55  ...                  1     17.0       16.0   1710.0
# 4 2024-10-30 15:07:49  ...                  1      NaN        NaN      NaN
#
#   R_Score F_Score M_Score RFM_Total_Score                   Cluster  \
# 0     0.0     0.0     0.0             0.0  8 - Zero Value/No Orders
# 1     0.0     0.0     0.0             0.0  8 - Zero Value/No Orders
# 2     1.0     3.0     4.0             8.0         3 - Aspiring Fans
# 3     4.0     4.0     3.0            11.0            1 - High Value
# 4     0.0     0.0     0.0             0.0  8 - Zero Value/No Orders
#
#   Months_Since_Last_Order
# 0                     NaN
# 1                     NaN
# 2               22.006579
# 3                0.559211
# 4                     NaN
#
# [5 rows x 42 columns]

# %%
# --- 检查每个 cluster 的人数和分布 ---

# 1. 人数统计和百分比
cluster_counts = rfm_clustered_df['Cluster'].value_counts().reset_index()
cluster_counts.columns = ['Cluster', 'Count']
total_customers = cluster_counts['Count'].sum()
cluster_counts['Percentage'] = (cluster_counts['Count'] / total_customers).round(4)

# 2. 平均 RFM 分数
cluster_avg_rfm = rfm_clustered_df.groupby('Cluster')[['Recency','Frequency','Monetary','RFM_Total_Score']].mean().reset_index()
cluster_avg_rfm = cluster_avg_rfm.round(2)


# print("--- 客户分群结果 (RFM Clustered Data Head) ---")
# print(rfm_clustered_df[['member_uid', 'R_Score', 'F_Score', 'M_Score', 'RFM_Total_Score', 'Recency', 'Months_Since_Last_Order', 'Cluster']].head(10))

print("\n--- Cluster 人数分布 ---")
print(cluster_counts.sort_values(by='Cluster'))

print("\n--- Cluster 平均 RFM 分数 ---")
print(cluster_avg_rfm.sort_values(by='Cluster'))
# Out:
# --- Cluster 人数分布 ---
#                     Cluster   Count  Percentage
# 4            1 - High Value   70175      0.0658
# 3                  2 - Fans   90506      0.0849
# 1         3 - Aspiring Fans  117484      0.1102
# 5             4 - Newcomers   27086      0.0254
# 6               5 - Passive    5548      0.0052
# 7                  6 - Lost    1009      0.0009
# 2             7 - Low Value  103511      0.0971
# 0  8 - Zero Value/No Orders  651027      0.6105
#
# --- Cluster 平均 RFM 分数 ---
#                     Cluster  Recency  Frequency  Monetary  RFM_Total_Score
# 0            1 - High Value    74.14       6.58   5749.13            11.45
# 1                  2 - Fans   261.43       3.78   3389.56             9.48
# 2         3 - Aspiring Fans   252.29       1.62   1414.67             7.03
# 3             4 - Newcomers    43.70       1.00    896.03             6.66
# 4               5 - Passive   948.78       1.68   1905.65             5.53
# 5                  6 - Lost  1189.84       1.70   1810.49             5.69
# 6             7 - Low Value   440.84       1.01    981.13             4.40
# 7  8 - Zero Value/No Orders      NaN        NaN       NaN             0.00

# %%
rfm_clustered_df.shape
# Out:
# (1066346, 42)

# %%
# --- by EC ---

rfm_clustered_df_ec = rfm_clustered_df[rfm_clustered_df['member_channel']!='DTC-RETAIL']

# 1. 人数统计和百分比
cluster_counts_ec = rfm_clustered_df_ec['Cluster'].value_counts().reset_index()
cluster_counts_ec.columns = ['Cluster', 'Count']
total_customers_ec = cluster_counts_ec['Count'].sum()
cluster_counts_ec['Percentage'] = (cluster_counts_ec['Count'] / total_customers_ec).round(4)

# 2. 平均 RFM 分数
cluster_avg_rfm_ec = rfm_clustered_df_ec.groupby('Cluster')[['Recency','Frequency','Monetary', 'RFM_Total_Score']].mean().reset_index()
cluster_avg_rfm_ec = cluster_avg_rfm_ec.round(2)


# print("--- 客户分群结果 (RFM Clustered Data Head) ---")
# print(rfm_clustered_df[['member_uid', 'R_Score', 'F_Score', 'M_Score', 'RFM_Total_Score', 'Recency', 'Months_Since_Last_Order', 'Cluster']].head(10))

print("\n--- EC Cluster 人数分布 ---")
print(cluster_counts_ec.sort_values(by='Cluster'))

print("\n--- EC Cluster 平均 RFM 分数 ---")
print(cluster_avg_rfm_ec.sort_values(by='Cluster'))
# Out:
# --- EC Cluster 人数分布 ---
#                     Cluster   Count  Percentage
# 4            1 - High Value   33623      0.0406
# 2                  2 - Fans   42259      0.0511
# 1         3 - Aspiring Fans   52742      0.0637
# 5             4 - Newcomers   12905      0.0156
# 6               5 - Passive    2342      0.0028
# 7                  6 - Lost     972      0.0012
# 3             7 - Low Value   39704      0.0480
# 0  8 - Zero Value/No Orders  643011      0.7770
#
# --- EC Cluster 平均 RFM 分数 ---
#                     Cluster  Recency  Frequency  Monetary  RFM_Total_Score
# 0            1 - High Value    71.29       8.04   5741.19            11.48
# 1                  2 - Fans   213.36       4.11   2917.03             9.49
# 2         3 - Aspiring Fans   219.75       1.92   1119.20             7.13
# 3             4 - Newcomers    40.65       1.00    661.88             6.46
# 4               5 - Passive   977.96       1.89   2086.67             5.72
# 5                  6 - Lost  1188.94       1.71   1810.05             5.70
# 6             7 - Low Value   347.82       1.02    708.56             4.44
# 7  8 - Zero Value/No Orders      NaN        NaN       NaN             0.00

# %%
# --- by RETAIL ---

rfm_clustered_df_retail = rfm_clustered_df[rfm_clustered_df['member_channel']=='DTC-RETAIL']

# 1. 人数统计和百分比
cluster_counts_retail = rfm_clustered_df_retail['Cluster'].value_counts().reset_index()
cluster_counts_retail.columns = ['Cluster', 'Count']
total_customers_retail = cluster_counts_retail['Count'].sum()
cluster_counts_retail['Percentage'] = (cluster_counts_retail['Count'] / total_customers_retail).round(4)

# 2. 平均 RFM 分数
cluster_avg_rfm_retail = rfm_clustered_df_retail.groupby('Cluster')[['Recency','Frequency','Monetary', 'RFM_Total_Score']].mean().reset_index()
cluster_avg_rfm_retail = cluster_avg_rfm_retail.round(2)


# print("--- 客户分群结果 (RFM Clustered Data Head) ---")
# print(rfm_clustered_df[['member_uid', 'R_Score', 'F_Score', 'M_Score', 'RFM_Total_Score', 'Recency', 'Months_Since_Last_Order', 'Cluster']].head(10))

print("\n--- Retail Cluster 人数分布 ---")
print(cluster_counts_retail.sort_values(by='Cluster'))

print("\n--- Retail Cluster 平均 RFM 分数 ---")
print(cluster_avg_rfm_retail.sort_values(by='Cluster'))
# Out:
# --- Retail Cluster 人数分布 ---
#                     Cluster  Count  Percentage
# 3            1 - High Value  36552      0.1531
# 2                  2 - Fans  48247      0.2020
# 0         3 - Aspiring Fans  64742      0.2711
# 4             4 - Newcomers  14181      0.0594
# 6               5 - Passive   3206      0.0134
# 7                  6 - Lost     37      0.0002
# 1             7 - Low Value  63807      0.2672
# 5  8 - Zero Value/No Orders   8016      0.0336
#
# --- Retail Cluster 平均 RFM 分数 ---
#                     Cluster  Recency  Frequency  Monetary  RFM_Total_Score
# 0            1 - High Value    76.75       5.24   5756.43            11.42
# 1                  2 - Fans   303.53       3.49   3803.45             9.48
# 2         3 - Aspiring Fans   278.80       1.37   1655.38             6.95
# 3             4 - Newcomers    46.48       1.00   1109.10             6.85
# 4               5 - Passive   927.46       1.52   1773.41             5.40
# 5                  6 - Lost  1213.65       1.57   1822.04             5.65
# 6             7 - Low Value   498.72       1.01   1150.74             4.38
# 7  8 - Zero Value/No Orders      NaN        NaN       NaN             0.00

# %%
rfm_clustered_df.head()
# Out:
#   member_channel   member_store store_code     store_name  \
# 0   DTC-Mp & Web       Mp & Web       None           None
# 1   DTC-Mp & Web       Mp & Web       None           None
# 2     DTC-RETAIL  On昂跑 深圳益田假日广场      S0017  On昂跑 深圳益田假日广场
# 3   DTC-Mp & Web       Mp & Web       None           None
# 4   DTC-Mp & Web       Mp & Web       None           None
#
#                              member_uid                        member_uid_one  \
# 0  4af0541c-148f-4f5c-a9f3-7e434b7f09f2  4af0541c-148f-4f5c-a9f3-7e434b7f09f2
# 1  9cf1e32c-e4b3-49c1-bd38-fbaf93552a33  9cf1e32c-e4b3-49c1-bd38-fbaf93552a33
# 2  14749aac-e36a-4477-bfa1-fede3b3c3fe4  14749aac-e36a-4477-bfa1-fede3b3c3fe4
# 3  793d6c2d-2230-4e64-8287-176a78e0a8bd  793d6c2d-2230-4e64-8287-176a78e0a8bd
# 4  e69b772c-34c0-49de-80c9-92f4dc256a7c  e69b772c-34c0-49de-80c9-92f4dc256a7c
#
#   is_omni_channel_member  is register dtc register_channel  \
# 0                   true                1        Wechat Mp
# 1                   true                1        Wechat Mp
# 2                   true                1        Wechat Mp
# 3                   true                1        Wechat Mp
# 4                   true                1        Wechat Mp
#
#         register_time  ... member_uid_one_flg  Recency  Frequency Monetary  \
# 0 2025-10-20 15:04:02  ...                  1      NaN        NaN      NaN
# 1 2024-10-22 00:46:16  ...                  1      NaN        NaN      NaN
# 2 2024-01-11 16:21:10  ...                  1    662.0        2.0   2480.0
# 3 2025-04-01 17:48:55  ...                  1     10.0       30.0   1710.0
# 4 2024-10-30 15:07:49  ...                  1      NaN        NaN      NaN
#
#   R_Score F_Score M_Score RFM_Total_Score               Cluster  \
# 0     0.0     0.0     0.0             0.0  Zero Value/No Orders
# 1     0.0     0.0     0.0             0.0  Zero Value/No Orders
# 2     1.0     2.0     4.0             7.0         Aspiring Fans
# 3     4.0     4.0     3.0            11.0            High Value
# 4     0.0     0.0     0.0             0.0  Zero Value/No Orders
#
#   Months_Since_Last_Order
# 0                     NaN
# 1                     NaN
# 2               21.776316
# 3                0.328947
# 4                     NaN
#
# [5 rows x 42 columns]

# %%
# # --- 2. 按 store 和 Cluster 进行分组计算 (核心修改) ---

# channel_col = 'member_store' # 渠道列名

# # 2.1. 计算每个 Store/Cluster 的人数分布

# # 按 Store 和 Cluster 分组计数
# cluster_channel_counts = rfm_clustered_df.groupby([channel_col, 'Cluster']).size().reset_index(name='Count')

# # 计算每个 Store 内的百分比 (即：该 Cluster 在其所属 Channel 中的占比)
# # 1. 算出每个 Store 的总人数
# channel_totals = rfm_clustered_df[channel_col].value_counts().reset_index()
# channel_totals.columns = [channel_col, 'Channel_Total']

# # 2. 合并总人数并计算百分比
# cluster_channel_counts = pd.merge(cluster_channel_counts, channel_totals, on=channel_col, how='left')
# cluster_channel_counts['Percentage_of_Channel'] = (cluster_channel_counts['Count'] / cluster_channel_counts['Channel_Total']).round(4)
# cluster_channel_counts = cluster_channel_counts.drop(columns=['Channel_Total'])

# # 2.2. 计算每个 Store/Cluster 的平均 RFM 分数

# cluster_channel_avg_rfm = rfm_clustered_df.groupby([channel_col, 'Cluster'])[
#     ['R_Score', 'F_Score', 'M_Score', 'RFM_Total_Score']
# ].mean().reset_index()
# cluster_channel_avg_rfm = cluster_channel_avg_rfm.round(2)


# # --- 3. 打印结果 ---

# print("--- 客户分群结果 (RFM Clustered Data Head) ---")
# # 打印最终分类结果
# print(rfm_clustered_df[['member_uid', channel_col, 'Cluster', 'RFM_Total_Score']].head(12).to_markdown(index=False))

# print("\n--- 按 Member Channel 和 Cluster 划分的人数分布 ---")
# print(cluster_channel_counts.to_markdown(index=False))

# print("\n--- 按 Member Channel 和 Cluster 划分的平均 RFM 分数 ---")
# print(cluster_channel_avg_rfm.to_markdown(index=False))
# Out:
# --- 客户分群结果 (RFM Clustered Data Head) ---
# | member_uid                           | member_store            | Cluster       |   RFM_Total_Score |
# |:-------------------------------------|:------------------------|:--------------|------------------:|
# | 14749aac-e36a-4477-bfa1-fede3b3c3fe4 | On昂跑 深圳益田假日广场 | Aspiring Fans |                 7 |
# | 142a2891-6887-4066-8844-4afcc2d551df | On昂跑 广州太古汇       | Newcomers     |                 7 |
# | ce47f1ba-04b9-4733-a43e-ede1fb9a007d | On昂跑 北京国贸店       | Low Value     |                 4 |
# | 55dca87a-48fb-4844-a891-a9d1b38c265e | On昂跑 北京APM店        | Aspiring Fans |                 7 |
# | ba70c210-e907-4063-b40a-666642d8f06e | On昂跑 成都IFS店        | Aspiring Fans |                 6 |
# | 58688ed5-cd7b-4ef6-b93b-38bfe96779c4 | On昂跑 北京国贸店       | Aspiring Fans |                 6 |
# | 928fd9dc-e7b6-43fa-8da1-86c0a4243454 | On昂跑 北京APM店        | Aspiring Fans |                 8 |
# | 2bc6f2ae-bc9b-4d7b-9bfd-94466467ad76 | On昂跑 成都太古里       | Aspiring Fans |                 8 |
# | 818fd5c8-6b42-460a-b1e1-1383fe74ae0d | On昂跑 上海静安嘉里     | Aspiring Fans |                 8 |
# | b79cdc24-4a69-450d-b2d3-fb381466cbd5 | On昂跑 南京万象天地     | Aspiring Fans |                 7 |
# | 5d96e781-c1c4-49e4-8f67-fec0bca21da6 | On昂跑 成都IFS店        | Low Value     |                 5 |
# | 50b221ea-c358-4183-add3-8c72eeafaba4 | On昂跑 上海比斯特店     | Aspiring Fans |                 6 |
#
# --- 按 Member Channel 和 Cluster 划分的人数分布 ---
# | member_store              | Cluster              |   Count |   Percentage_of_Channel |
# |:--------------------------|:---------------------|--------:|------------------------:|
# | On昂跑 上海万象城店       | Aspiring Fans        |    2053 |                  0.33   |
# | On昂跑 上海万象城店       | Fans                 |    1274 |                  0.2048 |
# | On昂跑 上海万象城店       | High Value           |     749 |                  0.1204 |
# | On昂跑 上海万象城店       | Lost                 |       1 |                  0.0002 |
# | On昂跑 上海万象城店       | Low Value            |    1507 |                  0.2422 |
# | On昂跑 上海万象城店       | Newcomers            |     505 |                  0.0812 |
# | On昂跑 上海万象城店       | Zero Value/No Orders |     132 |                  0.0212 |
# | On昂跑 上海世纪汇         | Aspiring Fans        |    2410 |                  0.3318 |
# | On昂跑 上海世纪汇         | Fans                 |    1394 |                  0.1919 |
# | On昂跑 上海世纪汇         | High Value           |     713 |                  0.0982 |
# | On昂跑 上海世纪汇         | Low Value            |    2008 |                  0.2765 |
# | On昂跑 上海世纪汇         | Newcomers            |     620 |                  0.0854 |
# | On昂跑 上海世纪汇         | Zero Value/No Orders |     118 |                  0.0162 |
# | On昂跑 上海兴业太古汇     | Aspiring Fans        |    1580 |                  0.2764 |
# | On昂跑 上海兴业太古汇     | Fans                 |    1231 |                  0.2153 |
# | On昂跑 上海兴业太古汇     | High Value           |     645 |                  0.1128 |
# | On昂跑 上海兴业太古汇     | Low Value            |    1692 |                  0.296  |
# | On昂跑 上海兴业太古汇     | Newcomers            |     246 |                  0.043  |
# | On昂跑 上海兴业太古汇     | Passive              |     190 |                  0.0332 |
# | On昂跑 上海兴业太古汇     | Zero Value/No Orders |     133 |                  0.0233 |
# | On昂跑 上海新天地         | Aspiring Fans        |    3469 |                  0.3074 |
# | On昂跑 上海新天地         | Fans                 |    2398 |                  0.2125 |
# | On昂跑 上海新天地         | High Value           |    1428 |                  0.1265 |
# | On昂跑 上海新天地         | Lost                 |       1 |                  0.0001 |
# | On昂跑 上海新天地         | Low Value            |    2875 |                  0.2547 |
# | On昂跑 上海新天地         | Newcomers            |     546 |                  0.0484 |
# | On昂跑 上海新天地         | Passive              |     245 |                  0.0217 |
# | On昂跑 上海新天地         | Zero Value/No Orders |     324 |                  0.0287 |
# | On昂跑 上海比斯特店       | Aspiring Fans        |    4832 |                  0.3296 |
# | On昂跑 上海比斯特店       | Fans                 |    3075 |                  0.2097 |
# | On昂跑 上海比斯特店       | High Value           |    1676 |                  0.1143 |
# | On昂跑 上海比斯特店       | Lost                 |       1 |                  0.0001 |
# | On昂跑 上海比斯特店       | Low Value            |    3878 |                  0.2645 |
# | On昂跑 上海比斯特店       | Newcomers            |     571 |                  0.0389 |
# | On昂跑 上海比斯特店       | Passive              |       4 |                  0.0003 |
# | On昂跑 上海比斯特店       | Zero Value/No Orders |     625 |                  0.0426 |
# | On昂跑 上海浦东嘉里城     | Aspiring Fans        |    2356 |                  0.2934 |
# | On昂跑 上海浦东嘉里城     | Fans                 |    1608 |                  0.2002 |
# | On昂跑 上海浦东嘉里城     | High Value           |    1146 |                  0.1427 |
# | On昂跑 上海浦东嘉里城     | Lost                 |       3 |                  0.0004 |
# | On昂跑 上海浦东嘉里城     | Low Value            |    2123 |                  0.2644 |
# | On昂跑 上海浦东嘉里城     | Newcomers            |     506 |                  0.063  |
# | On昂跑 上海浦东嘉里城     | Passive              |     146 |                  0.0182 |
# | On昂跑 上海浦东嘉里城     | Zero Value/No Orders |     143 |                  0.0178 |
# | On昂跑 上海港汇恒隆广场店 | Aspiring Fans        |    1762 |                  0.2821 |
# | On昂跑 上海港汇恒隆广场店 | Fans                 |    1289 |                  0.2064 |
# | On昂跑 上海港汇恒隆广场店 | High Value           |     714 |                  0.1143 |
# | On昂跑 上海港汇恒隆广场店 | Lost                 |       2 |                  0.0003 |
# | On昂跑 上海港汇恒隆广场店 | Low Value            |    1900 |                  0.3042 |
# | On昂跑 上海港汇恒隆广场店 | Newcomers            |     249 |                  0.0399 |
# | On昂跑 上海港汇恒隆广场店 | Passive              |     169 |                  0.0271 |
# | On昂跑 上海港汇恒隆广场店 | Zero Value/No Orders |     160 |                  0.0256 |
# | On昂跑 上海环贸iapm       | Aspiring Fans        |    2095 |                  0.2992 |
# | On昂跑 上海环贸iapm       | Fans                 |    1354 |                  0.1934 |
# | On昂跑 上海环贸iapm       | High Value           |     795 |                  0.1136 |
# | On昂跑 上海环贸iapm       | Lost                 |       1 |                  0.0001 |
# | On昂跑 上海环贸iapm       | Low Value            |    1889 |                  0.2698 |
# | On昂跑 上海环贸iapm       | Newcomers            |     484 |                  0.0691 |
# | On昂跑 上海环贸iapm       | Passive              |     222 |                  0.0317 |
# | On昂跑 上海环贸iapm       | Zero Value/No Orders |     161 |                  0.023  |
# | On昂跑 上海西岸梦中心     | Aspiring Fans        |    1696 |                  0.3911 |
# | On昂跑 上海西岸梦中心     | Fans                 |     784 |                  0.1808 |
# | On昂跑 上海西岸梦中心     | High Value           |     438 |                  0.101  |
# | On昂跑 上海西岸梦中心     | Lost                 |       1 |                  0.0002 |
# | On昂跑 上海西岸梦中心     | Low Value            |     681 |                  0.1571 |
# | On昂跑 上海西岸梦中心     | Newcomers            |     472 |                  0.1089 |
# | On昂跑 上海西岸梦中心     | Zero Value/No Orders |     264 |                  0.0609 |
# | On昂跑 上海静安嘉里       | Aspiring Fans        |    4893 |                  0.3177 |
# | On昂跑 上海静安嘉里       | Fans                 |    3043 |                  0.1976 |
# | On昂跑 上海静安嘉里       | High Value           |    1694 |                  0.11   |
# | On昂跑 上海静安嘉里       | Lost                 |       4 |                  0.0003 |
# | On昂跑 上海静安嘉里       | Low Value            |    4088 |                  0.2654 |
# | On昂跑 上海静安嘉里       | Newcomers            |     836 |                  0.0543 |
# | On昂跑 上海静安嘉里       | Passive              |     244 |                  0.0158 |
# | On昂跑 上海静安嘉里       | Zero Value/No Orders |     601 |                  0.039  |
# | On昂跑 北京APM店          | Aspiring Fans        |    2874 |                  0.3484 |
# | On昂跑 北京APM店          | Fans                 |    1551 |                  0.188  |
# | On昂跑 北京APM店          | High Value           |     790 |                  0.0958 |
# | On昂跑 北京APM店          | Low Value            |    2128 |                  0.258  |
# | On昂跑 北京APM店          | Newcomers            |     731 |                  0.0886 |
# | On昂跑 北京APM店          | Zero Value/No Orders |     174 |                  0.0211 |
# | On昂跑 北京三里屯太古里   | Aspiring Fans        |    3575 |                  0.3022 |
# | On昂跑 北京三里屯太古里   | Fans                 |    1907 |                  0.1612 |
# | On昂跑 北京三里屯太古里   | High Value           |    1117 |                  0.0944 |
# | On昂跑 北京三里屯太古里   | Lost                 |       2 |                  0.0002 |
# | On昂跑 北京三里屯太古里   | Low Value            |    2847 |                  0.2407 |
# | On昂跑 北京三里屯太古里   | Newcomers            |     546 |                  0.0462 |
# | On昂跑 北京三里屯太古里   | Passive              |     180 |                  0.0152 |
# | On昂跑 北京三里屯太古里   | Zero Value/No Orders |    1655 |                  0.1399 |
# | On昂跑 北京世纪金源       | Aspiring Fans        |    1347 |                  0.4146 |
# | On昂跑 北京世纪金源       | Fans                 |     716 |                  0.2204 |
# | On昂跑 北京世纪金源       | High Value           |     439 |                  0.1351 |
# | On昂跑 北京世纪金源       | Low Value            |      46 |                  0.0142 |
# | On昂跑 北京世纪金源       | Newcomers            |     633 |                  0.1948 |
# | On昂跑 北京世纪金源       | Zero Value/No Orders |      68 |                  0.0209 |
# | On昂跑 北京合生汇店       | Aspiring Fans        |    3612 |                  0.3808 |
# | On昂跑 北京合生汇店       | Fans                 |    1836 |                  0.1935 |
# | On昂跑 北京合生汇店       | High Value           |    1003 |                  0.1057 |
# | On昂跑 北京合生汇店       | Low Value            |    2260 |                  0.2382 |
# | On昂跑 北京合生汇店       | Newcomers            |     611 |                  0.0644 |
# | On昂跑 北京合生汇店       | Zero Value/No Orders |     164 |                  0.0173 |
# | On昂跑 北京国贸店         | Aspiring Fans        |    3988 |                  0.3122 |
# | On昂跑 北京国贸店         | Fans                 |    2565 |                  0.2008 |
# | On昂跑 北京国贸店         | High Value           |    1352 |                  0.1058 |
# | On昂跑 北京国贸店         | Lost                 |       3 |                  0.0002 |
# | On昂跑 北京国贸店         | Low Value            |    3886 |                  0.3042 |
# | On昂跑 北京国贸店         | Newcomers            |     440 |                  0.0344 |
# | On昂跑 北京国贸店         | Passive              |     285 |                  0.0223 |
# | On昂跑 北京国贸店         | Zero Value/No Orders |     255 |                  0.02   |
# | On昂跑 北京荟聚           | Aspiring Fans        |    2488 |                  0.3741 |
# | On昂跑 北京荟聚           | Fans                 |    1197 |                  0.18   |
# | On昂跑 北京荟聚           | High Value           |     680 |                  0.1023 |
# | On昂跑 北京荟聚           | Low Value            |    1544 |                  0.2322 |
# | On昂跑 北京荟聚           | Newcomers            |     613 |                  0.0922 |
# | On昂跑 北京荟聚           | Zero Value/No Orders |     128 |                  0.0192 |
# | On昂跑 北京颐堤港店       | Aspiring Fans        |    2073 |                  0.3104 |
# | On昂跑 北京颐堤港店       | Fans                 |    1274 |                  0.1908 |
# | On昂跑 北京颐堤港店       | High Value           |     797 |                  0.1193 |
# | On昂跑 北京颐堤港店       | Lost                 |       1 |                  0.0001 |
# | On昂跑 北京颐堤港店       | Low Value            |    2019 |                  0.3023 |
# | On昂跑 北京颐堤港店       | Newcomers            |     282 |                  0.0422 |
# | On昂跑 北京颐堤港店       | Passive              |     158 |                  0.0237 |
# | On昂跑 北京颐堤港店       | Zero Value/No Orders |      74 |                  0.0111 |
# | On昂跑 南京万象天地       | Aspiring Fans        |    2702 |                  0.3981 |
# | On昂跑 南京万象天地       | Fans                 |    1323 |                  0.1949 |
# | On昂跑 南京万象天地       | High Value           |     887 |                  0.1307 |
# | On昂跑 南京万象天地       | Low Value            |    1201 |                  0.1769 |
# | On昂跑 南京万象天地       | Newcomers            |     602 |                  0.0887 |
# | On昂跑 南京万象天地       | Zero Value/No Orders |      73 |                  0.0108 |
# | On昂跑 天津佛罗伦萨       | Aspiring Fans        |    1926 |                  0.4054 |
# | On昂跑 天津佛罗伦萨       | Fans                 |     901 |                  0.1896 |
# | On昂跑 天津佛罗伦萨       | High Value           |     413 |                  0.0869 |
# | On昂跑 天津佛罗伦萨       | Low Value            |     920 |                  0.1936 |
# | On昂跑 天津佛罗伦萨       | Newcomers            |     343 |                  0.0722 |
# | On昂跑 天津佛罗伦萨       | Zero Value/No Orders |     248 |                  0.0522 |
# | On昂跑 广州IGC店          | Aspiring Fans        |    1569 |                  0.3563 |
# | On昂跑 广州IGC店          | Fans                 |     981 |                  0.2228 |
# | On昂跑 广州IGC店          | High Value           |     741 |                  0.1683 |
# | On昂跑 广州IGC店          | Low Value            |     533 |                  0.121  |
# | On昂跑 广州IGC店          | Newcomers            |     497 |                  0.1129 |
# | On昂跑 广州IGC店          | Zero Value/No Orders |      83 |                  0.0188 |
# | On昂跑 广州太古汇         | Aspiring Fans        |    4602 |                  0.3329 |
# | On昂跑 广州太古汇         | Fans                 |    3030 |                  0.2192 |
# | On昂跑 广州太古汇         | High Value           |    1928 |                  0.1394 |
# | On昂跑 广州太古汇         | Low Value            |    2876 |                  0.208  |
# | On昂跑 广州太古汇         | Newcomers            |    1101 |                  0.0796 |
# | On昂跑 广州太古汇         | Zero Value/No Orders |     289 |                  0.0209 |
# | On昂跑 成都IFS店          | Aspiring Fans        |    1918 |                  0.3526 |
# | On昂跑 成都IFS店          | Fans                 |    1117 |                  0.2054 |
# | On昂跑 成都IFS店          | High Value           |     663 |                  0.1219 |
# | On昂跑 成都IFS店          | Lost                 |       1 |                  0.0002 |
# | On昂跑 成都IFS店          | Low Value            |    1355 |                  0.2491 |
# | On昂跑 成都IFS店          | Newcomers            |     240 |                  0.0441 |
# | On昂跑 成都IFS店          | Zero Value/No Orders |     145 |                  0.0267 |
# | On昂跑 成都仁和新城店     | Aspiring Fans        |    2739 |                  0.2996 |
# | On昂跑 成都仁和新城店     | Fans                 |    1949 |                  0.2132 |
# | On昂跑 成都仁和新城店     | High Value           |    1467 |                  0.1605 |
# | On昂跑 成都仁和新城店     | Low Value            |    2214 |                  0.2422 |
# | On昂跑 成都仁和新城店     | Newcomers            |     491 |                  0.0537 |
# | On昂跑 成都仁和新城店     | Passive              |     118 |                  0.0129 |
# | On昂跑 成都仁和新城店     | Zero Value/No Orders |     163 |                  0.0178 |
# | On昂跑 成都佛罗伦萨奥莱店 | Aspiring Fans        |     459 |                  0.3004 |
# | On昂跑 成都佛罗伦萨奥莱店 | Fans                 |     323 |                  0.2114 |
# | On昂跑 成都佛罗伦萨奥莱店 | High Value           |     243 |                  0.159  |
# | On昂跑 成都佛罗伦萨奥莱店 | Low Value            |     333 |                  0.2179 |
# | On昂跑 成都佛罗伦萨奥莱店 | Newcomers            |     128 |                  0.0838 |
# | On昂跑 成都佛罗伦萨奥莱店 | Zero Value/No Orders |      42 |                  0.0275 |
# | On昂跑 成都太古里         | Aspiring Fans        |    5328 |                  0.3509 |
# | On昂跑 成都太古里         | Fans                 |    3164 |                  0.2084 |
# | On昂跑 成都太古里         | High Value           |    1919 |                  0.1264 |
# | On昂跑 成都太古里         | Lost                 |       9 |                  0.0006 |
# | On昂跑 成都太古里         | Low Value            |    3317 |                  0.2185 |
# | On昂跑 成都太古里         | Newcomers            |     730 |                  0.0481 |
# | On昂跑 成都太古里         | Passive              |     236 |                  0.0155 |
# | On昂跑 成都太古里         | Zero Value/No Orders |     481 |                  0.0317 |
# | On昂跑 成都太古里旗舰店   | Aspiring Fans        |     121 |                  0.4384 |
# | On昂跑 成都太古里旗舰店   | Fans                 |      65 |                  0.2355 |
# | On昂跑 成都太古里旗舰店   | High Value           |      46 |                  0.1667 |
# | On昂跑 成都太古里旗舰店   | Low Value            |       1 |                  0.0036 |
# | On昂跑 成都太古里旗舰店   | Newcomers            |      28 |                  0.1014 |
# | On昂跑 成都太古里旗舰店   | Zero Value/No Orders |      15 |                  0.0543 |
# | On昂跑 武汉SKP            | Aspiring Fans        |    2855 |                  0.3877 |
# | On昂跑 武汉SKP            | Fans                 |    1501 |                  0.2038 |
# | On昂跑 武汉SKP            | High Value           |     928 |                  0.126  |
# | On昂跑 武汉SKP            | Low Value            |    1375 |                  0.1867 |
# | On昂跑 武汉SKP            | Newcomers            |     485 |                  0.0659 |
# | On昂跑 武汉SKP            | Zero Value/No Orders |     220 |                  0.0299 |
# | On昂跑 深圳万象城一期     | Aspiring Fans        |    1264 |                  0.2851 |
# | On昂跑 深圳万象城一期     | Fans                 |     936 |                  0.2111 |
# | On昂跑 深圳万象城一期     | High Value           |     471 |                  0.1062 |
# | On昂跑 深圳万象城一期     | Lost                 |       3 |                  0.0007 |
# | On昂跑 深圳万象城一期     | Low Value            |    1324 |                  0.2987 |
# | On昂跑 深圳万象城一期     | Newcomers            |     146 |                  0.0329 |
# | On昂跑 深圳万象城一期     | Passive              |      87 |                  0.0196 |
# | On昂跑 深圳万象城一期     | Zero Value/No Orders |     202 |                  0.0456 |
# | On昂跑 深圳万象城三期店   | Aspiring Fans        |     832 |                  0.2887 |
# | On昂跑 深圳万象城三期店   | Fans                 |     538 |                  0.1867 |
# | On昂跑 深圳万象城三期店   | High Value           |     287 |                  0.0996 |
# | On昂跑 深圳万象城三期店   | Lost                 |       1 |                  0.0003 |
# | On昂跑 深圳万象城三期店   | Low Value            |     888 |                  0.3081 |
# | On昂跑 深圳万象城三期店   | Newcomers            |     142 |                  0.0493 |
# | On昂跑 深圳万象城三期店   | Passive              |      54 |                  0.0187 |
# | On昂跑 深圳万象城三期店   | Zero Value/No Orders |     140 |                  0.0486 |
# | On昂跑 深圳海岸城         | Aspiring Fans        |    2974 |                  0.3106 |
# | On昂跑 深圳海岸城         | Fans                 |    1983 |                  0.2071 |
# | On昂跑 深圳海岸城         | High Value           |    1071 |                  0.1119 |
# | On昂跑 深圳海岸城         | Lost                 |       1 |                  0.0001 |
# | On昂跑 深圳海岸城         | Low Value            |    2634 |                  0.2751 |
# | On昂跑 深圳海岸城         | Newcomers            |     478 |                  0.0499 |
# | On昂跑 深圳海岸城         | Passive              |     121 |                  0.0126 |
# | On昂跑 深圳海岸城         | Zero Value/No Orders |     312 |                  0.0326 |
# | On昂跑 深圳湾万象城       | Aspiring Fans        |       3 |                  0.2308 |
# | On昂跑 深圳湾万象城       | Fans                 |       3 |                  0.2308 |
# | On昂跑 深圳湾万象城       | High Value           |       3 |                  0.2308 |
# | On昂跑 深圳湾万象城       | Newcomers            |       4 |                  0.3077 |
# | On昂跑 深圳益田假日广场   | Aspiring Fans        |    1869 |                  0.3142 |
# | On昂跑 深圳益田假日广场   | Fans                 |    1259 |                  0.2117 |
# | On昂跑 深圳益田假日广场   | High Value           |     675 |                  0.1135 |
# | On昂跑 深圳益田假日广场   | Low Value            |    1632 |                  0.2744 |
# | On昂跑 深圳益田假日广场   | Newcomers            |     246 |                  0.0414 |
# | On昂跑 深圳益田假日广场   | Passive              |      71 |                  0.0119 |
# | On昂跑 深圳益田假日广场   | Zero Value/No Orders |     196 |                  0.033  |
# | 微信小店                  | Aspiring Fans        |      12 |                  0.0727 |
# | 微信小店                  | Fans                 |       3 |                  0.0182 |
# | 微信小店                  | High Value           |       3 |                  0.0182 |
# | 微信小店                  | Newcomers            |       7 |                  0.0424 |
# | 微信小店                  | Zero Value/No Orders |     140 |                  0.8485 |
#
# --- 按 Member Channel 和 Cluster 划分的平均 RFM 分数 ---
# | member_store              | Cluster              |   R_Score |   F_Score |   M_Score |   RFM_Total_Score |
# |:--------------------------|:---------------------|----------:|----------:|----------:|------------------:|
# | On昂跑 上海万象城店       | Aspiring Fans        |      2.32 |      1.66 |      2.89 |              6.87 |
# | On昂跑 上海万象城店       | Fans                 |      2.67 |      2.97 |      3.84 |              9.49 |
# | On昂跑 上海万象城店       | High Value           |      3.62 |      3.85 |      3.98 |             11.45 |
# | On昂跑 上海万象城店       | Lost                 |      1    |      1    |      2    |              4    |
# | On昂跑 上海万象城店       | Low Value            |      1.32 |      1.03 |      2.17 |              4.51 |
# | On昂跑 上海万象城店       | Newcomers            |      4    |      1.03 |      1.96 |              6.98 |
# | On昂跑 上海万象城店       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海世纪汇         | Aspiring Fans        |      2.35 |      1.66 |      2.81 |              6.82 |
# | On昂跑 上海世纪汇         | Fans                 |      2.66 |      2.97 |      3.84 |              9.47 |
# | On昂跑 上海世纪汇         | High Value           |      3.62 |      3.85 |      3.98 |             11.45 |
# | On昂跑 上海世纪汇         | Low Value            |      1.35 |      1.03 |      2.12 |              4.49 |
# | On昂跑 上海世纪汇         | Newcomers            |      4    |      1.03 |      1.96 |              6.99 |
# | On昂跑 上海世纪汇         | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海兴业太古汇     | Aspiring Fans        |      1.78 |      2.04 |      3.15 |              6.98 |
# | On昂跑 上海兴业太古汇     | Fans                 |      2.09 |      3.43 |      3.91 |              9.43 |
# | On昂跑 上海兴业太古汇     | High Value           |      3.6  |      3.9  |      3.99 |             11.49 |
# | On昂跑 上海兴业太古汇     | Low Value            |      1.15 |      1.03 |      2.21 |              4.39 |
# | On昂跑 上海兴业太古汇     | Newcomers            |      4    |      1.04 |      1.95 |              7    |
# | On昂跑 上海兴业太古汇     | Passive              |      1    |      1.58 |      2.77 |              5.35 |
# | On昂跑 上海兴业太古汇     | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海新天地         | Aspiring Fans        |      2.07 |      1.81 |      3.08 |              6.95 |
# | On昂跑 上海新天地         | Fans                 |      2.28 |      3.26 |      3.88 |              9.42 |
# | On昂跑 上海新天地         | High Value           |      3.59 |      3.87 |      3.98 |             11.45 |
# | On昂跑 上海新天地         | Lost                 |      1    |      2    |      3    |              6    |
# | On昂跑 上海新天地         | Low Value            |      1.23 |      1.04 |      2.22 |              4.49 |
# | On昂跑 上海新天地         | Newcomers            |      4    |      1.05 |      1.93 |              6.98 |
# | On昂跑 上海新天地         | Passive              |      1    |      1.6  |      2.82 |              5.42 |
# | On昂跑 上海新天地         | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海比斯特店       | Aspiring Fans        |      1.83 |      2.13 |      3.06 |              7.02 |
# | On昂跑 上海比斯特店       | Fans                 |      2.21 |      3.36 |      3.8  |              9.37 |
# | On昂跑 上海比斯特店       | High Value           |      3.62 |      3.85 |      3.98 |             11.44 |
# | On昂跑 上海比斯特店       | Lost                 |      1    |      1    |      2    |              4    |
# | On昂跑 上海比斯特店       | Low Value            |      1.13 |      1.09 |      1.94 |              4.16 |
# | On昂跑 上海比斯特店       | Newcomers            |      4    |      1.57 |      1.9  |              7.47 |
# | On昂跑 上海比斯特店       | Passive              |      1    |      1.25 |      3    |              5.25 |
# | On昂跑 上海比斯特店       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海浦东嘉里城     | Aspiring Fans        |      2.03 |      1.84 |      3.06 |              6.93 |
# | On昂跑 上海浦东嘉里城     | Fans                 |      2.32 |      3.26 |      3.89 |              9.47 |
# | On昂跑 上海浦东嘉里城     | High Value           |      3.62 |      3.87 |      3.99 |             11.49 |
# | On昂跑 上海浦东嘉里城     | Lost                 |      1    |      1    |      2.33 |              4.33 |
# | On昂跑 上海浦东嘉里城     | Low Value            |      1.2  |      1.03 |      2.21 |              4.44 |
# | On昂跑 上海浦东嘉里城     | Newcomers            |      4    |      1.03 |      1.96 |              6.99 |
# | On昂跑 上海浦东嘉里城     | Passive              |      1    |      1.68 |      2.91 |              5.59 |
# | On昂跑 上海浦东嘉里城     | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海港汇恒隆广场店 | Aspiring Fans        |      1.83 |      1.98 |      3.24 |              7.05 |
# | On昂跑 上海港汇恒隆广场店 | Fans                 |      2.17 |      3.32 |      3.94 |              9.43 |
# | On昂跑 上海港汇恒隆广场店 | High Value           |      3.62 |      3.89 |      3.99 |             11.51 |
# | On昂跑 上海港汇恒隆广场店 | Lost                 |      1    |      2    |      4    |              7    |
# | On昂跑 上海港汇恒隆广场店 | Low Value            |      1.16 |      1.02 |      2.25 |              4.43 |
# | On昂跑 上海港汇恒隆广场店 | Newcomers            |      4    |      1.06 |      1.94 |              7    |
# | On昂跑 上海港汇恒隆广场店 | Passive              |      1    |      1.51 |      2.77 |              5.28 |
# | On昂跑 上海港汇恒隆广场店 | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海环贸iapm       | Aspiring Fans        |      2.13 |      1.8  |      3.03 |              6.96 |
# | On昂跑 上海环贸iapm       | Fans                 |      2.43 |      3.18 |      3.85 |              9.45 |
# | On昂跑 上海环贸iapm       | High Value           |      3.6  |      3.87 |      3.99 |             11.46 |
# | On昂跑 上海环贸iapm       | Lost                 |      1    |      2    |      3    |              6    |
# | On昂跑 上海环贸iapm       | Low Value            |      1.18 |      1.03 |      2.21 |              4.42 |
# | On昂跑 上海环贸iapm       | Newcomers            |      4    |      1.05 |      1.93 |              6.98 |
# | On昂跑 上海环贸iapm       | Passive              |      1    |      1.48 |      2.69 |              5.18 |
# | On昂跑 上海环贸iapm       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海西岸梦中心     | Aspiring Fans        |      2.75 |      1.38 |      2.68 |              6.81 |
# | On昂跑 上海西岸梦中心     | Fans                 |      3.2  |      2.59 |      3.75 |              9.54 |
# | On昂跑 上海西岸梦中心     | High Value           |      3.65 |      3.79 |      3.98 |             11.42 |
# | On昂跑 上海西岸梦中心     | Lost                 |      1    |      1    |      3    |              5    |
# | On昂跑 上海西岸梦中心     | Low Value            |      1.82 |      1.02 |      1.96 |              4.8  |
# | On昂跑 上海西岸梦中心     | Newcomers            |      4    |      1.03 |      1.95 |              6.98 |
# | On昂跑 上海西岸梦中心     | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海静安嘉里       | Aspiring Fans        |      2.2  |      1.74 |      2.95 |              6.89 |
# | On昂跑 上海静安嘉里       | Fans                 |      2.41 |      3.15 |      3.87 |              9.43 |
# | On昂跑 上海静安嘉里       | High Value           |      3.62 |      3.87 |      3.98 |             11.48 |
# | On昂跑 上海静安嘉里       | Lost                 |      1    |      1.5  |      2.75 |              5.25 |
# | On昂跑 上海静安嘉里       | Low Value            |      1.28 |      1.04 |      2.17 |              4.49 |
# | On昂跑 上海静安嘉里       | Newcomers            |      4    |      1.05 |      1.94 |              6.98 |
# | On昂跑 上海静安嘉里       | Passive              |      1    |      1.56 |      2.67 |              5.23 |
# | On昂跑 上海静安嘉里       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 北京APM店          | Aspiring Fans        |      2.41 |      1.66 |      2.85 |              6.91 |
# | On昂跑 北京APM店          | Fans                 |      2.72 |      2.96 |      3.79 |              9.47 |
# | On昂跑 北京APM店          | High Value           |      3.62 |      3.84 |      3.98 |             11.44 |
# | On昂跑 北京APM店          | Low Value            |      1.29 |      1.04 |      2.17 |              4.5  |
# | On昂跑 北京APM店          | Newcomers            |      4    |      1.05 |      1.93 |              6.98 |
# | On昂跑 北京APM店          | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 北京三里屯太古里   | Aspiring Fans        |      2.27 |      1.66 |      2.97 |              6.91 |
# | On昂跑 北京三里屯太古里   | Fans                 |      2.5  |      3.09 |      3.87 |              9.45 |
# | On昂跑 北京三里屯太古里   | High Value           |      3.59 |      3.85 |      3.99 |             11.43 |
# | On昂跑 北京三里屯太古里   | Lost                 |      1    |      2    |      3.5  |              6.5  |
# | On昂跑 北京三里屯太古里   | Low Value            |      1.27 |      1.03 |      2.23 |              4.53 |
# | On昂跑 北京三里屯太古里   | Newcomers            |      4    |      1.03 |      1.94 |              6.97 |
# | On昂跑 北京三里屯太古里   | Passive              |      1    |      1.48 |      2.78 |              5.27 |
# | On昂跑 北京三里屯太古里   | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 北京世纪金源       | Aspiring Fans        |      3.3  |      1.18 |      2.49 |              6.97 |
# | On昂跑 北京世纪金源       | Fans                 |      3.63 |      2.27 |      3.64 |              9.54 |
# | On昂跑 北京世纪金源       | High Value           |      3.82 |      3.72 |      3.97 |             11.51 |
# | On昂跑 北京世纪金源       | Low Value            |      3    |      1    |      1    |              5    |
# | On昂跑 北京世纪金源       | Newcomers            |      4    |      1.08 |      1.9  |              6.98 |
# | On昂跑 北京世纪金源       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 北京合生汇店       | Aspiring Fans        |      2.47 |      1.58 |      2.76 |              6.81 |
# | On昂跑 北京合生汇店       | Fans                 |      2.78 |      2.88 |      3.81 |              9.47 |
# | On昂跑 北京合生汇店       | High Value           |      3.58 |      3.87 |      3.98 |             11.43 |
# | On昂跑 北京合生汇店       | Low Value            |      1.43 |      1.04 |      2.09 |              4.56 |
# | On昂跑 北京合生汇店       | Newcomers            |      4    |      1.05 |      1.94 |              6.99 |
# | On昂跑 北京合生汇店       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 北京国贸店         | Aspiring Fans        |      1.94 |      1.8  |      3.22 |              6.95 |
# | On昂跑 北京国贸店         | Fans                 |      2.27 |      3.22 |      3.91 |              9.4  |
# | On昂跑 北京国贸店         | High Value           |      3.6  |      3.87 |      3.99 |             11.46 |
# | On昂跑 北京国贸店         | Lost                 |      1    |      1    |      2.33 |              4.33 |
# | On昂跑 北京国贸店         | Low Value            |      1.19 |      1.03 |      2.23 |              4.44 |
# | On昂跑 北京国贸店         | Newcomers            |      4    |      1.05 |      1.93 |              6.98 |
# | On昂跑 北京国贸店         | Passive              |      1    |      1.56 |      2.71 |              5.27 |
# | On昂跑 北京国贸店         | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 北京荟聚           | Aspiring Fans        |      2.57 |      1.46 |      2.83 |              6.87 |
# | On昂跑 北京荟聚           | Fans                 |      2.91 |      2.77 |      3.82 |              9.5  |
# | On昂跑 北京荟聚           | High Value           |      3.61 |      3.83 |      3.99 |             11.42 |
# | On昂跑 北京荟聚           | Low Value            |      1.41 |      1.04 |      2.09 |              4.54 |
# | On昂跑 北京荟聚           | Newcomers            |      4    |      1.06 |      1.94 |              7    |
# | On昂跑 北京荟聚           | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 北京颐堤港店       | Aspiring Fans        |      1.98 |      1.88 |      3.11 |              6.97 |
# | On昂跑 北京颐堤港店       | Fans                 |      2.33 |      3.22 |      3.88 |              9.43 |
# | On昂跑 北京颐堤港店       | High Value           |      3.57 |      3.86 |      4    |             11.43 |
# | On昂跑 北京颐堤港店       | Lost                 |      1    |      2    |      4    |              7    |
# | On昂跑 北京颐堤港店       | Low Value            |      1.21 |      1.03 |      2.19 |              4.43 |
# | On昂跑 北京颐堤港店       | Newcomers            |      4    |      1.06 |      1.94 |              7    |
# | On昂跑 北京颐堤港店       | Passive              |      1    |      1.57 |      2.7  |              5.27 |
# | On昂跑 北京颐堤港店       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 南京万象天地       | Aspiring Fans        |      2.67 |      1.47 |      2.74 |              6.89 |
# | On昂跑 南京万象天地       | Fans                 |      3.02 |      2.72 |      3.78 |              9.52 |
# | On昂跑 南京万象天地       | High Value           |      3.62 |      3.85 |      3.98 |             11.44 |
# | On昂跑 南京万象天地       | Low Value            |      1.85 |      1.03 |      1.93 |              4.81 |
# | On昂跑 南京万象天地       | Newcomers            |      4    |      1.07 |      1.93 |              7    |
# | On昂跑 南京万象天地       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 天津佛罗伦萨       | Aspiring Fans        |      2.49 |      1.59 |      2.76 |              6.84 |
# | On昂跑 天津佛罗伦萨       | Fans                 |      2.7  |      3    |      3.83 |              9.52 |
# | On昂跑 天津佛罗伦萨       | High Value           |      3.65 |      3.77 |      3.99 |             11.4  |
# | On昂跑 天津佛罗伦萨       | Low Value            |      1.91 |      1.04 |      1.91 |              4.86 |
# | On昂跑 天津佛罗伦萨       | Newcomers            |      4    |      1.08 |      1.92 |              7    |
# | On昂跑 天津佛罗伦萨       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 广州IGC店          | Aspiring Fans        |      2.8  |      1.43 |      2.7  |              6.93 |
# | On昂跑 广州IGC店          | Fans                 |      3.16 |      2.63 |      3.75 |              9.54 |
# | On昂跑 广州IGC店          | High Value           |      3.67 |      3.8  |      3.97 |             11.45 |
# | On昂跑 广州IGC店          | Low Value            |      2.08 |      1.01 |      1.86 |              4.95 |
# | On昂跑 广州IGC店          | Newcomers            |      4    |      1.06 |      1.9  |              6.96 |
# | On昂跑 广州IGC店          | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 广州太古汇         | Aspiring Fans        |      2.36 |      1.63 |      3    |              6.99 |
# | On昂跑 广州太古汇         | Fans                 |      2.64 |      3.03 |      3.85 |              9.51 |
# | On昂跑 广州太古汇         | High Value           |      3.58 |      3.88 |      3.99 |             11.45 |
# | On昂跑 广州太古汇         | Low Value            |      1.39 |      1.03 |      2.16 |              4.58 |
# | On昂跑 广州太古汇         | Newcomers            |      4    |      1.04 |      1.94 |              6.97 |
# | On昂跑 广州太古汇         | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 成都IFS店          | Aspiring Fans        |      2.24 |      1.63 |      3    |              6.87 |
# | On昂跑 成都IFS店          | Fans                 |      2.58 |      3    |      3.89 |              9.47 |
# | On昂跑 成都IFS店          | High Value           |      3.59 |      3.84 |      4    |             11.43 |
# | On昂跑 成都IFS店          | Lost                 |      1    |      1    |      3    |              5    |
# | On昂跑 成都IFS店          | Low Value            |      1.3  |      1.03 |      2.18 |              4.51 |
# | On昂跑 成都IFS店          | Newcomers            |      4    |      1.03 |      1.99 |              7.02 |
# | On昂跑 成都IFS店          | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 成都仁和新城店     | Aspiring Fans        |      2.15 |      1.74 |      3.06 |              6.94 |
# | On昂跑 成都仁和新城店     | Fans                 |      2.46 |      3.14 |      3.88 |              9.48 |
# | On昂跑 成都仁和新城店     | High Value           |      3.62 |      3.88 |      3.99 |             11.49 |
# | On昂跑 成都仁和新城店     | Low Value            |      1.29 |      1.02 |      2.17 |              4.48 |
# | On昂跑 成都仁和新城店     | Newcomers            |      4    |      1.04 |      1.95 |              6.99 |
# | On昂跑 成都仁和新城店     | Passive              |      1    |      1.7  |      2.91 |              5.61 |
# | On昂跑 成都仁和新城店     | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 成都佛罗伦萨奥莱店 | Aspiring Fans        |      2.24 |      2    |      2.7  |              6.94 |
# | On昂跑 成都佛罗伦萨奥莱店 | Fans                 |      2.77 |      3.16 |      3.59 |              9.52 |
# | On昂跑 成都佛罗伦萨奥莱店 | High Value           |      3.73 |      3.84 |      3.95 |             11.51 |
# | On昂跑 成都佛罗伦萨奥莱店 | Low Value            |      1.34 |      1.17 |      1.84 |              4.35 |
# | On昂跑 成都佛罗伦萨奥莱店 | Newcomers            |      4    |      1.56 |      1.85 |              7.41 |
# | On昂跑 成都佛罗伦萨奥莱店 | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 成都太古里         | Aspiring Fans        |      2.36 |      1.57 |      3    |              6.94 |
# | On昂跑 成都太古里         | Fans                 |      2.53 |      2.99 |      3.89 |              9.41 |
# | On昂跑 成都太古里         | High Value           |      3.6  |      3.85 |      3.99 |             11.44 |
# | On昂跑 成都太古里         | Lost                 |      1    |      1.67 |      2.78 |              5.44 |
# | On昂跑 成都太古里         | Low Value            |      1.28 |      1.02 |      2.2  |              4.51 |
# | On昂跑 成都太古里         | Newcomers            |      4    |      1.04 |      1.95 |              6.99 |
# | On昂跑 成都太古里         | Passive              |      1    |      1.72 |      2.92 |              5.64 |
# | On昂跑 成都太古里         | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 成都太古里旗舰店   | Aspiring Fans        |      3.16 |      1.26 |      2.43 |              6.84 |
# | On昂跑 成都太古里旗舰店   | Fans                 |      3.6  |      2.6  |      3.23 |              9.43 |
# | On昂跑 成都太古里旗舰店   | High Value           |      3.74 |      3.83 |      3.96 |             11.52 |
# | On昂跑 成都太古里旗舰店   | Low Value            |      3    |      1    |      1    |              5    |
# | On昂跑 成都太古里旗舰店   | Newcomers            |      4    |      1.11 |      1.89 |              7    |
# | On昂跑 成都太古里旗舰店   | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 武汉SKP            | Aspiring Fans        |      2.61 |      1.43 |      2.92 |              6.96 |
# | On昂跑 武汉SKP            | Fans                 |      2.88 |      2.79 |      3.86 |              9.53 |
# | On昂跑 武汉SKP            | High Value           |      3.62 |      3.84 |      3.98 |             11.45 |
# | On昂跑 武汉SKP            | Low Value            |      1.72 |      1.02 |      1.99 |              4.73 |
# | On昂跑 武汉SKP            | Newcomers            |      4    |      1.05 |      1.92 |              6.97 |
# | On昂跑 武汉SKP            | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 深圳万象城一期     | Aspiring Fans        |      1.95 |      1.81 |      3.15 |              6.91 |
# | On昂跑 深圳万象城一期     | Fans                 |      2.23 |      3.27 |      3.93 |              9.44 |
# | On昂跑 深圳万象城一期     | High Value           |      3.62 |      3.87 |      3.99 |             11.48 |
# | On昂跑 深圳万象城一期     | Lost                 |      1    |      1.67 |      3.33 |              6    |
# | On昂跑 深圳万象城一期     | Low Value            |      1.34 |      1.02 |      2.15 |              4.51 |
# | On昂跑 深圳万象城一期     | Newcomers            |      4    |      1.08 |      1.96 |              7.03 |
# | On昂跑 深圳万象城一期     | Passive              |      1    |      1.72 |      2.93 |              5.66 |
# | On昂跑 深圳万象城一期     | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 深圳万象城三期店   | Aspiring Fans        |      2.01 |      1.82 |      3.12 |              6.95 |
# | On昂跑 深圳万象城三期店   | Fans                 |      2.27 |      3.23 |      3.91 |              9.41 |
# | On昂跑 深圳万象城三期店   | High Value           |      3.63 |      3.83 |      3.99 |             11.45 |
# | On昂跑 深圳万象城三期店   | Lost                 |      1    |      1    |      2    |              4    |
# | On昂跑 深圳万象城三期店   | Low Value            |      1.13 |      1.01 |      2.19 |              4.34 |
# | On昂跑 深圳万象城三期店   | Newcomers            |      4    |      1.01 |      1.93 |              6.94 |
# | On昂跑 深圳万象城三期店   | Passive              |      1    |      1.63 |      2.81 |              5.44 |
# | On昂跑 深圳万象城三期店   | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 深圳海岸城         | Aspiring Fans        |      2.08 |      1.82 |      3.06 |              6.96 |
# | On昂跑 深圳海岸城         | Fans                 |      2.36 |      3.18 |      3.88 |              9.43 |
# | On昂跑 深圳海岸城         | High Value           |      3.62 |      3.87 |      3.99 |             11.48 |
# | On昂跑 深圳海岸城         | Lost                 |      1    |      1    |      2    |              4    |
# | On昂跑 深圳海岸城         | Low Value            |      1.26 |      1.03 |      2.14 |              4.43 |
# | On昂跑 深圳海岸城         | Newcomers            |      4    |      1.05 |      1.95 |              7    |
# | On昂跑 深圳海岸城         | Passive              |      1    |      1.53 |      2.71 |              5.24 |
# | On昂跑 深圳海岸城         | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 深圳湾万象城       | Aspiring Fans        |      4    |      1    |      3    |              8    |
# | On昂跑 深圳湾万象城       | Fans                 |      4    |      2    |      3.67 |              9.67 |
# | On昂跑 深圳湾万象城       | High Value           |      4    |      3.67 |      4    |             11.67 |
# | On昂跑 深圳湾万象城       | Newcomers            |      4    |      1.25 |      1.75 |              7    |
# | On昂跑 深圳益田假日广场   | Aspiring Fans        |      2.06 |      1.85 |      3.03 |              6.94 |
# | On昂跑 深圳益田假日广场   | Fans                 |      2.22 |      3.32 |      3.89 |              9.44 |
# | On昂跑 深圳益田假日广场   | High Value           |      3.62 |      3.86 |      3.99 |             11.47 |
# | On昂跑 深圳益田假日广场   | Low Value            |      1.3  |      1.02 |      2.14 |              4.47 |
# | On昂跑 深圳益田假日广场   | Newcomers            |      4    |      1.08 |      1.9  |              6.98 |
# | On昂跑 深圳益田假日广场   | Passive              |      1    |      1.62 |      2.87 |              5.49 |
# | On昂跑 深圳益田假日广场   | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | 微信小店                  | Aspiring Fans        |      3.17 |      1.33 |      1.83 |              6.33 |
# | 微信小店                  | Fans                 |      4    |      1.67 |      3.67 |              9.33 |
# | 微信小店                  | High Value           |      3.67 |      4    |      4    |             11.67 |
# | 微信小店                  | Newcomers            |      4    |      1    |      1.86 |              6.86 |
# | 微信小店                  | Zero Value/No Orders |      0    |      0    |      0    |              0    |

# %%
channel_col = 'member_store' 
# 如果不确定，则从现有数据中获取所有不重复的 cluster 名称：
all_clusters = sorted(rfm_clustered_df_retail['Cluster'].unique().tolist())
all_channels = rfm_clustered_df_retail[channel_col].unique().tolist()

# --- 2.1. 计算每个 Channel/Cluster 的人数分布 (已修正为包含所有 Cluster 并显示 0) ---

# 1. 计算按 Channel 和 Cluster 分组的计数，并用 reindex 确保所有组合都有，缺失值填充 0
# 创建完整的 (Channel, Cluster) 组合索引
full_index = pd.MultiIndex.from_product([all_channels, all_clusters], names=[channel_col, 'Cluster'])

# 按 Channel 和 Cluster 分组计数，然后用 reindex 确保所有组合都在，并填充 0
cluster_channel_counts_raw = rfm_clustered_df_retail.groupby([channel_col, 'Cluster']).size()
cluster_channel_counts = cluster_channel_counts_raw.reindex(full_index, fill_value=0).reset_index(name='Count')

# 2. 计算每个 Channel (Store) 内的百分比 (即：该 Cluster 在其所属 Channel 中的占比)
# 算出每个 Channel 的总人数
channel_totals = rfm_clustered_df_retail[channel_col].value_counts().reset_index()
channel_totals.columns = [channel_col, 'Channel_Total']

# 合并总人数并计算百分比
cluster_channel_counts = pd.merge(cluster_channel_counts, channel_totals, on=channel_col, how='left')
# 'Percentage_of_Channel' 保持不变，代表该 Cluster 在其所属 Store (Channel) 中的占比
cluster_channel_counts['Percentage_of_Channel'] = (cluster_channel_counts['Count'] / cluster_channel_counts['Channel_Total']).round(4)
cluster_channel_counts = cluster_channel_counts.drop(columns=['Channel_Total'])


# 3. 计算整个 'channel_col' (所有门店合计) 的 RFM 人数分布 (新需求)
total_members = len(rfm_clustered_df_retail)

# 计算每个 Cluster 在总人数中的占比
overall_cluster_distribution = rfm_clustered_df_retail.groupby('Cluster').size().reset_index(name='Overall_Count')

# 确保 'overall_cluster_distribution' 中也包含所有 Cluster，缺失值填充 0
overall_cluster_distribution = overall_cluster_distribution.set_index('Cluster').reindex(all_clusters, fill_value=0).reset_index()

overall_cluster_distribution['Percentage_of_Overall_Channel'] = (overall_cluster_distribution['Overall_Count'] / total_members).round(4)

# 只需要百分比列，并重命名以供合并
overall_cluster_distribution = overall_cluster_distribution[['Cluster', 'Percentage_of_Overall_Channel']]

# 4. 将整体分布合并到门店分布表中
cluster_channel_counts = pd.merge(
    cluster_channel_counts,
    overall_cluster_distribution,
    on='Cluster',
    how='left'
).sort_values(by=[channel_col, 'Cluster']).reset_index(drop=True)


# 2.2. 计算每个 Channel/Cluster 的平均 RFM 分数 (保持不变)

cluster_channel_avg_rfm = rfm_clustered_df_retail.groupby([channel_col, 'Cluster'])[
    ['R_Score', 'F_Score', 'M_Score', 'RFM_Total_Score']
].mean().reset_index()
cluster_channel_avg_rfm = cluster_channel_avg_rfm.round(2)


# --- 3. 打印结果 ---

print("--- 客户分群结果 (RFM Clustered Data Head) ---")
# 打印最终分类结果
print(rfm_clustered_df_retail[['member_uid', channel_col, 'Cluster', 'RFM_Total_Score']].head(12).to_markdown(index=False))

print("\n--- 按 Member Channel 和 Cluster 划分的人数分布 ---")
print(cluster_channel_counts.to_markdown(index=False))

print("\n--- 按 Member Channel 和 Cluster 划分的平均 RFM 分数 ---")
print(cluster_channel_avg_rfm.to_markdown(index=False))
# Out:
# --- 客户分群结果 (RFM Clustered Data Head) ---
# | member_uid                           | member_store            | Cluster       |   RFM_Total_Score |
# |:-------------------------------------|:------------------------|:--------------|------------------:|
# | 14749aac-e36a-4477-bfa1-fede3b3c3fe4 | On昂跑 深圳益田假日广场 | Aspiring Fans |                 7 |
# | 142a2891-6887-4066-8844-4afcc2d551df | On昂跑 广州太古汇       | Newcomers     |                 7 |
# | ce47f1ba-04b9-4733-a43e-ede1fb9a007d | On昂跑 北京国贸店       | Low Value     |                 4 |
# | 55dca87a-48fb-4844-a891-a9d1b38c265e | On昂跑 北京APM店        | Aspiring Fans |                 7 |
# | ba70c210-e907-4063-b40a-666642d8f06e | On昂跑 成都IFS店        | Aspiring Fans |                 6 |
# | 58688ed5-cd7b-4ef6-b93b-38bfe96779c4 | On昂跑 北京国贸店       | Aspiring Fans |                 6 |
# | 928fd9dc-e7b6-43fa-8da1-86c0a4243454 | On昂跑 北京APM店        | Aspiring Fans |                 8 |
# | 2bc6f2ae-bc9b-4d7b-9bfd-94466467ad76 | On昂跑 成都太古里       | Aspiring Fans |                 8 |
# | 818fd5c8-6b42-460a-b1e1-1383fe74ae0d | On昂跑 上海静安嘉里     | Aspiring Fans |                 8 |
# | b79cdc24-4a69-450d-b2d3-fb381466cbd5 | On昂跑 南京万象天地     | Aspiring Fans |                 7 |
# | 5d96e781-c1c4-49e4-8f67-fec0bca21da6 | On昂跑 成都IFS店        | Low Value     |                 5 |
# | 50b221ea-c358-4183-add3-8c72eeafaba4 | On昂跑 上海比斯特店     | Aspiring Fans |                 6 |
#
# --- 按 Member Channel 和 Cluster 划分的人数分布 ---
# | member_store              | Cluster              |   Count |   Percentage_of_Channel |   Percentage_of_Overall_Channel |
# |:--------------------------|:---------------------|--------:|------------------------:|--------------------------------:|
# | On昂跑 上海万象城店       | Aspiring Fans        |    2053 |                  0.33   |                          0.3306 |
# | On昂跑 上海万象城店       | Fans                 |    1274 |                  0.2048 |                          0.2009 |
# | On昂跑 上海万象城店       | High Value           |     749 |                  0.1204 |                          0.1179 |
# | On昂跑 上海万象城店       | Lost                 |       1 |                  0.0002 |                          0.0001 |
# | On昂跑 上海万象城店       | Low Value            |    1507 |                  0.2422 |                          0.2448 |
# | On昂跑 上海万象城店       | Newcomers            |     505 |                  0.0812 |                          0.0615 |
# | On昂跑 上海万象城店       | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 上海万象城店       | Zero Value/No Orders |     132 |                  0.0212 |                          0.0335 |
# | On昂跑 上海世纪汇         | Aspiring Fans        |    2410 |                  0.3318 |                          0.3306 |
# | On昂跑 上海世纪汇         | Fans                 |    1394 |                  0.1919 |                          0.2009 |
# | On昂跑 上海世纪汇         | High Value           |     713 |                  0.0982 |                          0.1179 |
# | On昂跑 上海世纪汇         | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 上海世纪汇         | Low Value            |    2008 |                  0.2765 |                          0.2448 |
# | On昂跑 上海世纪汇         | Newcomers            |     620 |                  0.0854 |                          0.0615 |
# | On昂跑 上海世纪汇         | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 上海世纪汇         | Zero Value/No Orders |     118 |                  0.0162 |                          0.0335 |
# | On昂跑 上海兴业太古汇     | Aspiring Fans        |    1580 |                  0.2764 |                          0.3306 |
# | On昂跑 上海兴业太古汇     | Fans                 |    1231 |                  0.2153 |                          0.2009 |
# | On昂跑 上海兴业太古汇     | High Value           |     645 |                  0.1128 |                          0.1179 |
# | On昂跑 上海兴业太古汇     | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 上海兴业太古汇     | Low Value            |    1692 |                  0.296  |                          0.2448 |
# | On昂跑 上海兴业太古汇     | Newcomers            |     246 |                  0.043  |                          0.0615 |
# | On昂跑 上海兴业太古汇     | Passive              |     190 |                  0.0332 |                          0.0107 |
# | On昂跑 上海兴业太古汇     | Zero Value/No Orders |     133 |                  0.0233 |                          0.0335 |
# | On昂跑 上海新天地         | Aspiring Fans        |    3469 |                  0.3074 |                          0.3306 |
# | On昂跑 上海新天地         | Fans                 |    2398 |                  0.2125 |                          0.2009 |
# | On昂跑 上海新天地         | High Value           |    1428 |                  0.1265 |                          0.1179 |
# | On昂跑 上海新天地         | Lost                 |       1 |                  0.0001 |                          0.0001 |
# | On昂跑 上海新天地         | Low Value            |    2875 |                  0.2547 |                          0.2448 |
# | On昂跑 上海新天地         | Newcomers            |     546 |                  0.0484 |                          0.0615 |
# | On昂跑 上海新天地         | Passive              |     245 |                  0.0217 |                          0.0107 |
# | On昂跑 上海新天地         | Zero Value/No Orders |     324 |                  0.0287 |                          0.0335 |
# | On昂跑 上海比斯特店       | Aspiring Fans        |    4832 |                  0.3296 |                          0.3306 |
# | On昂跑 上海比斯特店       | Fans                 |    3075 |                  0.2097 |                          0.2009 |
# | On昂跑 上海比斯特店       | High Value           |    1676 |                  0.1143 |                          0.1179 |
# | On昂跑 上海比斯特店       | Lost                 |       1 |                  0.0001 |                          0.0001 |
# | On昂跑 上海比斯特店       | Low Value            |    3878 |                  0.2645 |                          0.2448 |
# | On昂跑 上海比斯特店       | Newcomers            |     571 |                  0.0389 |                          0.0615 |
# | On昂跑 上海比斯特店       | Passive              |       4 |                  0.0003 |                          0.0107 |
# | On昂跑 上海比斯特店       | Zero Value/No Orders |     625 |                  0.0426 |                          0.0335 |
# | On昂跑 上海浦东嘉里城     | Aspiring Fans        |    2356 |                  0.2934 |                          0.3306 |
# | On昂跑 上海浦东嘉里城     | Fans                 |    1608 |                  0.2002 |                          0.2009 |
# | On昂跑 上海浦东嘉里城     | High Value           |    1146 |                  0.1427 |                          0.1179 |
# | On昂跑 上海浦东嘉里城     | Lost                 |       3 |                  0.0004 |                          0.0001 |
# | On昂跑 上海浦东嘉里城     | Low Value            |    2123 |                  0.2644 |                          0.2448 |
# | On昂跑 上海浦东嘉里城     | Newcomers            |     506 |                  0.063  |                          0.0615 |
# | On昂跑 上海浦东嘉里城     | Passive              |     146 |                  0.0182 |                          0.0107 |
# | On昂跑 上海浦东嘉里城     | Zero Value/No Orders |     143 |                  0.0178 |                          0.0335 |
# | On昂跑 上海港汇恒隆广场店 | Aspiring Fans        |    1762 |                  0.2821 |                          0.3306 |
# | On昂跑 上海港汇恒隆广场店 | Fans                 |    1289 |                  0.2064 |                          0.2009 |
# | On昂跑 上海港汇恒隆广场店 | High Value           |     714 |                  0.1143 |                          0.1179 |
# | On昂跑 上海港汇恒隆广场店 | Lost                 |       2 |                  0.0003 |                          0.0001 |
# | On昂跑 上海港汇恒隆广场店 | Low Value            |    1900 |                  0.3042 |                          0.2448 |
# | On昂跑 上海港汇恒隆广场店 | Newcomers            |     249 |                  0.0399 |                          0.0615 |
# | On昂跑 上海港汇恒隆广场店 | Passive              |     169 |                  0.0271 |                          0.0107 |
# | On昂跑 上海港汇恒隆广场店 | Zero Value/No Orders |     160 |                  0.0256 |                          0.0335 |
# | On昂跑 上海环贸iapm       | Aspiring Fans        |    2095 |                  0.2992 |                          0.3306 |
# | On昂跑 上海环贸iapm       | Fans                 |    1354 |                  0.1934 |                          0.2009 |
# | On昂跑 上海环贸iapm       | High Value           |     795 |                  0.1136 |                          0.1179 |
# | On昂跑 上海环贸iapm       | Lost                 |       1 |                  0.0001 |                          0.0001 |
# | On昂跑 上海环贸iapm       | Low Value            |    1889 |                  0.2698 |                          0.2448 |
# | On昂跑 上海环贸iapm       | Newcomers            |     484 |                  0.0691 |                          0.0615 |
# | On昂跑 上海环贸iapm       | Passive              |     222 |                  0.0317 |                          0.0107 |
# | On昂跑 上海环贸iapm       | Zero Value/No Orders |     161 |                  0.023  |                          0.0335 |
# | On昂跑 上海西岸梦中心     | Aspiring Fans        |    1696 |                  0.3911 |                          0.3306 |
# | On昂跑 上海西岸梦中心     | Fans                 |     784 |                  0.1808 |                          0.2009 |
# | On昂跑 上海西岸梦中心     | High Value           |     438 |                  0.101  |                          0.1179 |
# | On昂跑 上海西岸梦中心     | Lost                 |       1 |                  0.0002 |                          0.0001 |
# | On昂跑 上海西岸梦中心     | Low Value            |     681 |                  0.1571 |                          0.2448 |
# | On昂跑 上海西岸梦中心     | Newcomers            |     472 |                  0.1089 |                          0.0615 |
# | On昂跑 上海西岸梦中心     | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 上海西岸梦中心     | Zero Value/No Orders |     264 |                  0.0609 |                          0.0335 |
# | On昂跑 上海静安嘉里       | Aspiring Fans        |    4893 |                  0.3177 |                          0.3306 |
# | On昂跑 上海静安嘉里       | Fans                 |    3043 |                  0.1976 |                          0.2009 |
# | On昂跑 上海静安嘉里       | High Value           |    1694 |                  0.11   |                          0.1179 |
# | On昂跑 上海静安嘉里       | Lost                 |       4 |                  0.0003 |                          0.0001 |
# | On昂跑 上海静安嘉里       | Low Value            |    4088 |                  0.2654 |                          0.2448 |
# | On昂跑 上海静安嘉里       | Newcomers            |     836 |                  0.0543 |                          0.0615 |
# | On昂跑 上海静安嘉里       | Passive              |     244 |                  0.0158 |                          0.0107 |
# | On昂跑 上海静安嘉里       | Zero Value/No Orders |     601 |                  0.039  |                          0.0335 |
# | On昂跑 北京APM店          | Aspiring Fans        |    2874 |                  0.3484 |                          0.3306 |
# | On昂跑 北京APM店          | Fans                 |    1551 |                  0.188  |                          0.2009 |
# | On昂跑 北京APM店          | High Value           |     790 |                  0.0958 |                          0.1179 |
# | On昂跑 北京APM店          | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 北京APM店          | Low Value            |    2128 |                  0.258  |                          0.2448 |
# | On昂跑 北京APM店          | Newcomers            |     731 |                  0.0886 |                          0.0615 |
# | On昂跑 北京APM店          | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 北京APM店          | Zero Value/No Orders |     174 |                  0.0211 |                          0.0335 |
# | On昂跑 北京三里屯太古里   | Aspiring Fans        |    3575 |                  0.3022 |                          0.3306 |
# | On昂跑 北京三里屯太古里   | Fans                 |    1907 |                  0.1612 |                          0.2009 |
# | On昂跑 北京三里屯太古里   | High Value           |    1117 |                  0.0944 |                          0.1179 |
# | On昂跑 北京三里屯太古里   | Lost                 |       2 |                  0.0002 |                          0.0001 |
# | On昂跑 北京三里屯太古里   | Low Value            |    2847 |                  0.2407 |                          0.2448 |
# | On昂跑 北京三里屯太古里   | Newcomers            |     546 |                  0.0462 |                          0.0615 |
# | On昂跑 北京三里屯太古里   | Passive              |     180 |                  0.0152 |                          0.0107 |
# | On昂跑 北京三里屯太古里   | Zero Value/No Orders |    1655 |                  0.1399 |                          0.0335 |
# | On昂跑 北京世纪金源       | Aspiring Fans        |    1347 |                  0.4146 |                          0.3306 |
# | On昂跑 北京世纪金源       | Fans                 |     716 |                  0.2204 |                          0.2009 |
# | On昂跑 北京世纪金源       | High Value           |     439 |                  0.1351 |                          0.1179 |
# | On昂跑 北京世纪金源       | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 北京世纪金源       | Low Value            |      46 |                  0.0142 |                          0.2448 |
# | On昂跑 北京世纪金源       | Newcomers            |     633 |                  0.1948 |                          0.0615 |
# | On昂跑 北京世纪金源       | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 北京世纪金源       | Zero Value/No Orders |      68 |                  0.0209 |                          0.0335 |
# | On昂跑 北京合生汇店       | Aspiring Fans        |    3612 |                  0.3808 |                          0.3306 |
# | On昂跑 北京合生汇店       | Fans                 |    1836 |                  0.1935 |                          0.2009 |
# | On昂跑 北京合生汇店       | High Value           |    1003 |                  0.1057 |                          0.1179 |
# | On昂跑 北京合生汇店       | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 北京合生汇店       | Low Value            |    2260 |                  0.2382 |                          0.2448 |
# | On昂跑 北京合生汇店       | Newcomers            |     611 |                  0.0644 |                          0.0615 |
# | On昂跑 北京合生汇店       | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 北京合生汇店       | Zero Value/No Orders |     164 |                  0.0173 |                          0.0335 |
# | On昂跑 北京国贸店         | Aspiring Fans        |    3988 |                  0.3122 |                          0.3306 |
# | On昂跑 北京国贸店         | Fans                 |    2565 |                  0.2008 |                          0.2009 |
# | On昂跑 北京国贸店         | High Value           |    1352 |                  0.1058 |                          0.1179 |
# | On昂跑 北京国贸店         | Lost                 |       3 |                  0.0002 |                          0.0001 |
# | On昂跑 北京国贸店         | Low Value            |    3886 |                  0.3042 |                          0.2448 |
# | On昂跑 北京国贸店         | Newcomers            |     440 |                  0.0344 |                          0.0615 |
# | On昂跑 北京国贸店         | Passive              |     285 |                  0.0223 |                          0.0107 |
# | On昂跑 北京国贸店         | Zero Value/No Orders |     255 |                  0.02   |                          0.0335 |
# | On昂跑 北京荟聚           | Aspiring Fans        |    2488 |                  0.3741 |                          0.3306 |
# | On昂跑 北京荟聚           | Fans                 |    1197 |                  0.18   |                          0.2009 |
# | On昂跑 北京荟聚           | High Value           |     680 |                  0.1023 |                          0.1179 |
# | On昂跑 北京荟聚           | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 北京荟聚           | Low Value            |    1544 |                  0.2322 |                          0.2448 |
# | On昂跑 北京荟聚           | Newcomers            |     613 |                  0.0922 |                          0.0615 |
# | On昂跑 北京荟聚           | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 北京荟聚           | Zero Value/No Orders |     128 |                  0.0192 |                          0.0335 |
# | On昂跑 北京颐堤港店       | Aspiring Fans        |    2073 |                  0.3104 |                          0.3306 |
# | On昂跑 北京颐堤港店       | Fans                 |    1274 |                  0.1908 |                          0.2009 |
# | On昂跑 北京颐堤港店       | High Value           |     797 |                  0.1193 |                          0.1179 |
# | On昂跑 北京颐堤港店       | Lost                 |       1 |                  0.0001 |                          0.0001 |
# | On昂跑 北京颐堤港店       | Low Value            |    2019 |                  0.3023 |                          0.2448 |
# | On昂跑 北京颐堤港店       | Newcomers            |     282 |                  0.0422 |                          0.0615 |
# | On昂跑 北京颐堤港店       | Passive              |     158 |                  0.0237 |                          0.0107 |
# | On昂跑 北京颐堤港店       | Zero Value/No Orders |      74 |                  0.0111 |                          0.0335 |
# | On昂跑 南京万象天地       | Aspiring Fans        |    2702 |                  0.3981 |                          0.3306 |
# | On昂跑 南京万象天地       | Fans                 |    1323 |                  0.1949 |                          0.2009 |
# | On昂跑 南京万象天地       | High Value           |     887 |                  0.1307 |                          0.1179 |
# | On昂跑 南京万象天地       | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 南京万象天地       | Low Value            |    1201 |                  0.1769 |                          0.2448 |
# | On昂跑 南京万象天地       | Newcomers            |     602 |                  0.0887 |                          0.0615 |
# | On昂跑 南京万象天地       | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 南京万象天地       | Zero Value/No Orders |      73 |                  0.0108 |                          0.0335 |
# | On昂跑 天津佛罗伦萨       | Aspiring Fans        |    1926 |                  0.4054 |                          0.3306 |
# | On昂跑 天津佛罗伦萨       | Fans                 |     901 |                  0.1896 |                          0.2009 |
# | On昂跑 天津佛罗伦萨       | High Value           |     413 |                  0.0869 |                          0.1179 |
# | On昂跑 天津佛罗伦萨       | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 天津佛罗伦萨       | Low Value            |     920 |                  0.1936 |                          0.2448 |
# | On昂跑 天津佛罗伦萨       | Newcomers            |     343 |                  0.0722 |                          0.0615 |
# | On昂跑 天津佛罗伦萨       | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 天津佛罗伦萨       | Zero Value/No Orders |     248 |                  0.0522 |                          0.0335 |
# | On昂跑 广州IGC店          | Aspiring Fans        |    1569 |                  0.3563 |                          0.3306 |
# | On昂跑 广州IGC店          | Fans                 |     981 |                  0.2228 |                          0.2009 |
# | On昂跑 广州IGC店          | High Value           |     741 |                  0.1683 |                          0.1179 |
# | On昂跑 广州IGC店          | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 广州IGC店          | Low Value            |     533 |                  0.121  |                          0.2448 |
# | On昂跑 广州IGC店          | Newcomers            |     497 |                  0.1129 |                          0.0615 |
# | On昂跑 广州IGC店          | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 广州IGC店          | Zero Value/No Orders |      83 |                  0.0188 |                          0.0335 |
# | On昂跑 广州太古汇         | Aspiring Fans        |    4602 |                  0.3329 |                          0.3306 |
# | On昂跑 广州太古汇         | Fans                 |    3030 |                  0.2192 |                          0.2009 |
# | On昂跑 广州太古汇         | High Value           |    1928 |                  0.1394 |                          0.1179 |
# | On昂跑 广州太古汇         | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 广州太古汇         | Low Value            |    2876 |                  0.208  |                          0.2448 |
# | On昂跑 广州太古汇         | Newcomers            |    1101 |                  0.0796 |                          0.0615 |
# | On昂跑 广州太古汇         | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 广州太古汇         | Zero Value/No Orders |     289 |                  0.0209 |                          0.0335 |
# | On昂跑 成都IFS店          | Aspiring Fans        |    1918 |                  0.3526 |                          0.3306 |
# | On昂跑 成都IFS店          | Fans                 |    1117 |                  0.2054 |                          0.2009 |
# | On昂跑 成都IFS店          | High Value           |     663 |                  0.1219 |                          0.1179 |
# | On昂跑 成都IFS店          | Lost                 |       1 |                  0.0002 |                          0.0001 |
# | On昂跑 成都IFS店          | Low Value            |    1355 |                  0.2491 |                          0.2448 |
# | On昂跑 成都IFS店          | Newcomers            |     240 |                  0.0441 |                          0.0615 |
# | On昂跑 成都IFS店          | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 成都IFS店          | Zero Value/No Orders |     145 |                  0.0267 |                          0.0335 |
# | On昂跑 成都仁和新城店     | Aspiring Fans        |    2739 |                  0.2996 |                          0.3306 |
# | On昂跑 成都仁和新城店     | Fans                 |    1949 |                  0.2132 |                          0.2009 |
# | On昂跑 成都仁和新城店     | High Value           |    1467 |                  0.1605 |                          0.1179 |
# | On昂跑 成都仁和新城店     | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 成都仁和新城店     | Low Value            |    2214 |                  0.2422 |                          0.2448 |
# | On昂跑 成都仁和新城店     | Newcomers            |     491 |                  0.0537 |                          0.0615 |
# | On昂跑 成都仁和新城店     | Passive              |     118 |                  0.0129 |                          0.0107 |
# | On昂跑 成都仁和新城店     | Zero Value/No Orders |     163 |                  0.0178 |                          0.0335 |
# | On昂跑 成都佛罗伦萨奥莱店 | Aspiring Fans        |     459 |                  0.3004 |                          0.3306 |
# | On昂跑 成都佛罗伦萨奥莱店 | Fans                 |     323 |                  0.2114 |                          0.2009 |
# | On昂跑 成都佛罗伦萨奥莱店 | High Value           |     243 |                  0.159  |                          0.1179 |
# | On昂跑 成都佛罗伦萨奥莱店 | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 成都佛罗伦萨奥莱店 | Low Value            |     333 |                  0.2179 |                          0.2448 |
# | On昂跑 成都佛罗伦萨奥莱店 | Newcomers            |     128 |                  0.0838 |                          0.0615 |
# | On昂跑 成都佛罗伦萨奥莱店 | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 成都佛罗伦萨奥莱店 | Zero Value/No Orders |      42 |                  0.0275 |                          0.0335 |
# | On昂跑 成都太古里         | Aspiring Fans        |    5328 |                  0.3509 |                          0.3306 |
# | On昂跑 成都太古里         | Fans                 |    3164 |                  0.2084 |                          0.2009 |
# | On昂跑 成都太古里         | High Value           |    1919 |                  0.1264 |                          0.1179 |
# | On昂跑 成都太古里         | Lost                 |       9 |                  0.0006 |                          0.0001 |
# | On昂跑 成都太古里         | Low Value            |    3317 |                  0.2185 |                          0.2448 |
# | On昂跑 成都太古里         | Newcomers            |     730 |                  0.0481 |                          0.0615 |
# | On昂跑 成都太古里         | Passive              |     236 |                  0.0155 |                          0.0107 |
# | On昂跑 成都太古里         | Zero Value/No Orders |     481 |                  0.0317 |                          0.0335 |
# | On昂跑 成都太古里旗舰店   | Aspiring Fans        |     121 |                  0.4384 |                          0.3306 |
# | On昂跑 成都太古里旗舰店   | Fans                 |      65 |                  0.2355 |                          0.2009 |
# | On昂跑 成都太古里旗舰店   | High Value           |      46 |                  0.1667 |                          0.1179 |
# | On昂跑 成都太古里旗舰店   | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 成都太古里旗舰店   | Low Value            |       1 |                  0.0036 |                          0.2448 |
# | On昂跑 成都太古里旗舰店   | Newcomers            |      28 |                  0.1014 |                          0.0615 |
# | On昂跑 成都太古里旗舰店   | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 成都太古里旗舰店   | Zero Value/No Orders |      15 |                  0.0543 |                          0.0335 |
# | On昂跑 武汉SKP            | Aspiring Fans        |    2855 |                  0.3877 |                          0.3306 |
# | On昂跑 武汉SKP            | Fans                 |    1501 |                  0.2038 |                          0.2009 |
# | On昂跑 武汉SKP            | High Value           |     928 |                  0.126  |                          0.1179 |
# | On昂跑 武汉SKP            | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 武汉SKP            | Low Value            |    1375 |                  0.1867 |                          0.2448 |
# | On昂跑 武汉SKP            | Newcomers            |     485 |                  0.0659 |                          0.0615 |
# | On昂跑 武汉SKP            | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 武汉SKP            | Zero Value/No Orders |     220 |                  0.0299 |                          0.0335 |
# | On昂跑 深圳万象城一期     | Aspiring Fans        |    1264 |                  0.2851 |                          0.3306 |
# | On昂跑 深圳万象城一期     | Fans                 |     936 |                  0.2111 |                          0.2009 |
# | On昂跑 深圳万象城一期     | High Value           |     471 |                  0.1062 |                          0.1179 |
# | On昂跑 深圳万象城一期     | Lost                 |       3 |                  0.0007 |                          0.0001 |
# | On昂跑 深圳万象城一期     | Low Value            |    1324 |                  0.2987 |                          0.2448 |
# | On昂跑 深圳万象城一期     | Newcomers            |     146 |                  0.0329 |                          0.0615 |
# | On昂跑 深圳万象城一期     | Passive              |      87 |                  0.0196 |                          0.0107 |
# | On昂跑 深圳万象城一期     | Zero Value/No Orders |     202 |                  0.0456 |                          0.0335 |
# | On昂跑 深圳万象城三期店   | Aspiring Fans        |     832 |                  0.2887 |                          0.3306 |
# | On昂跑 深圳万象城三期店   | Fans                 |     538 |                  0.1867 |                          0.2009 |
# | On昂跑 深圳万象城三期店   | High Value           |     287 |                  0.0996 |                          0.1179 |
# | On昂跑 深圳万象城三期店   | Lost                 |       1 |                  0.0003 |                          0.0001 |
# | On昂跑 深圳万象城三期店   | Low Value            |     888 |                  0.3081 |                          0.2448 |
# | On昂跑 深圳万象城三期店   | Newcomers            |     142 |                  0.0493 |                          0.0615 |
# | On昂跑 深圳万象城三期店   | Passive              |      54 |                  0.0187 |                          0.0107 |
# | On昂跑 深圳万象城三期店   | Zero Value/No Orders |     140 |                  0.0486 |                          0.0335 |
# | On昂跑 深圳海岸城         | Aspiring Fans        |    2974 |                  0.3106 |                          0.3306 |
# | On昂跑 深圳海岸城         | Fans                 |    1983 |                  0.2071 |                          0.2009 |
# | On昂跑 深圳海岸城         | High Value           |    1071 |                  0.1119 |                          0.1179 |
# | On昂跑 深圳海岸城         | Lost                 |       1 |                  0.0001 |                          0.0001 |
# | On昂跑 深圳海岸城         | Low Value            |    2634 |                  0.2751 |                          0.2448 |
# | On昂跑 深圳海岸城         | Newcomers            |     478 |                  0.0499 |                          0.0615 |
# | On昂跑 深圳海岸城         | Passive              |     121 |                  0.0126 |                          0.0107 |
# | On昂跑 深圳海岸城         | Zero Value/No Orders |     312 |                  0.0326 |                          0.0335 |
# | On昂跑 深圳湾万象城       | Aspiring Fans        |       3 |                  0.2308 |                          0.3306 |
# | On昂跑 深圳湾万象城       | Fans                 |       3 |                  0.2308 |                          0.2009 |
# | On昂跑 深圳湾万象城       | High Value           |       3 |                  0.2308 |                          0.1179 |
# | On昂跑 深圳湾万象城       | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 深圳湾万象城       | Low Value            |       0 |                  0      |                          0.2448 |
# | On昂跑 深圳湾万象城       | Newcomers            |       4 |                  0.3077 |                          0.0615 |
# | On昂跑 深圳湾万象城       | Passive              |       0 |                  0      |                          0.0107 |
# | On昂跑 深圳湾万象城       | Zero Value/No Orders |       0 |                  0      |                          0.0335 |
# | On昂跑 深圳益田假日广场   | Aspiring Fans        |    1869 |                  0.3142 |                          0.3306 |
# | On昂跑 深圳益田假日广场   | Fans                 |    1259 |                  0.2117 |                          0.2009 |
# | On昂跑 深圳益田假日广场   | High Value           |     675 |                  0.1135 |                          0.1179 |
# | On昂跑 深圳益田假日广场   | Lost                 |       0 |                  0      |                          0.0001 |
# | On昂跑 深圳益田假日广场   | Low Value            |    1632 |                  0.2744 |                          0.2448 |
# | On昂跑 深圳益田假日广场   | Newcomers            |     246 |                  0.0414 |                          0.0615 |
# | On昂跑 深圳益田假日广场   | Passive              |      71 |                  0.0119 |                          0.0107 |
# | On昂跑 深圳益田假日广场   | Zero Value/No Orders |     196 |                  0.033  |                          0.0335 |
# | 微信小店                  | Aspiring Fans        |      12 |                  0.0727 |                          0.3306 |
# | 微信小店                  | Fans                 |       3 |                  0.0182 |                          0.2009 |
# | 微信小店                  | High Value           |       3 |                  0.0182 |                          0.1179 |
# | 微信小店                  | Lost                 |       0 |                  0      |                          0.0001 |
# | 微信小店                  | Low Value            |       0 |                  0      |                          0.2448 |
# | 微信小店                  | Newcomers            |       7 |                  0.0424 |                          0.0615 |
# | 微信小店                  | Passive              |       0 |                  0      |                          0.0107 |
# | 微信小店                  | Zero Value/No Orders |     140 |                  0.8485 |                          0.0335 |
#
# --- 按 Member Channel 和 Cluster 划分的平均 RFM 分数 ---
# | member_store              | Cluster              |   R_Score |   F_Score |   M_Score |   RFM_Total_Score |
# |:--------------------------|:---------------------|----------:|----------:|----------:|------------------:|
# | On昂跑 上海万象城店       | Aspiring Fans        |      2.32 |      1.66 |      2.89 |              6.87 |
# | On昂跑 上海万象城店       | Fans                 |      2.67 |      2.97 |      3.84 |              9.49 |
# | On昂跑 上海万象城店       | High Value           |      3.62 |      3.85 |      3.98 |             11.45 |
# | On昂跑 上海万象城店       | Lost                 |      1    |      1    |      2    |              4    |
# | On昂跑 上海万象城店       | Low Value            |      1.32 |      1.03 |      2.17 |              4.51 |
# | On昂跑 上海万象城店       | Newcomers            |      4    |      1.03 |      1.96 |              6.98 |
# | On昂跑 上海万象城店       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海世纪汇         | Aspiring Fans        |      2.35 |      1.66 |      2.81 |              6.82 |
# | On昂跑 上海世纪汇         | Fans                 |      2.66 |      2.97 |      3.84 |              9.47 |
# | On昂跑 上海世纪汇         | High Value           |      3.62 |      3.85 |      3.98 |             11.45 |
# | On昂跑 上海世纪汇         | Low Value            |      1.35 |      1.03 |      2.12 |              4.49 |
# | On昂跑 上海世纪汇         | Newcomers            |      4    |      1.03 |      1.96 |              6.99 |
# | On昂跑 上海世纪汇         | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海兴业太古汇     | Aspiring Fans        |      1.78 |      2.04 |      3.15 |              6.98 |
# | On昂跑 上海兴业太古汇     | Fans                 |      2.09 |      3.43 |      3.91 |              9.43 |
# | On昂跑 上海兴业太古汇     | High Value           |      3.6  |      3.9  |      3.99 |             11.49 |
# | On昂跑 上海兴业太古汇     | Low Value            |      1.15 |      1.03 |      2.21 |              4.39 |
# | On昂跑 上海兴业太古汇     | Newcomers            |      4    |      1.04 |      1.95 |              7    |
# | On昂跑 上海兴业太古汇     | Passive              |      1    |      1.58 |      2.77 |              5.35 |
# | On昂跑 上海兴业太古汇     | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海新天地         | Aspiring Fans        |      2.07 |      1.81 |      3.08 |              6.95 |
# | On昂跑 上海新天地         | Fans                 |      2.28 |      3.26 |      3.88 |              9.42 |
# | On昂跑 上海新天地         | High Value           |      3.59 |      3.87 |      3.98 |             11.45 |
# | On昂跑 上海新天地         | Lost                 |      1    |      2    |      3    |              6    |
# | On昂跑 上海新天地         | Low Value            |      1.23 |      1.04 |      2.22 |              4.49 |
# | On昂跑 上海新天地         | Newcomers            |      4    |      1.05 |      1.93 |              6.98 |
# | On昂跑 上海新天地         | Passive              |      1    |      1.6  |      2.82 |              5.42 |
# | On昂跑 上海新天地         | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海比斯特店       | Aspiring Fans        |      1.83 |      2.13 |      3.06 |              7.02 |
# | On昂跑 上海比斯特店       | Fans                 |      2.21 |      3.36 |      3.8  |              9.37 |
# | On昂跑 上海比斯特店       | High Value           |      3.62 |      3.85 |      3.98 |             11.44 |
# | On昂跑 上海比斯特店       | Lost                 |      1    |      1    |      2    |              4    |
# | On昂跑 上海比斯特店       | Low Value            |      1.13 |      1.09 |      1.94 |              4.16 |
# | On昂跑 上海比斯特店       | Newcomers            |      4    |      1.57 |      1.9  |              7.47 |
# | On昂跑 上海比斯特店       | Passive              |      1    |      1.25 |      3    |              5.25 |
# | On昂跑 上海比斯特店       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海浦东嘉里城     | Aspiring Fans        |      2.03 |      1.84 |      3.06 |              6.93 |
# | On昂跑 上海浦东嘉里城     | Fans                 |      2.32 |      3.26 |      3.89 |              9.47 |
# | On昂跑 上海浦东嘉里城     | High Value           |      3.62 |      3.87 |      3.99 |             11.49 |
# | On昂跑 上海浦东嘉里城     | Lost                 |      1    |      1    |      2.33 |              4.33 |
# | On昂跑 上海浦东嘉里城     | Low Value            |      1.2  |      1.03 |      2.21 |              4.44 |
# | On昂跑 上海浦东嘉里城     | Newcomers            |      4    |      1.03 |      1.96 |              6.99 |
# | On昂跑 上海浦东嘉里城     | Passive              |      1    |      1.68 |      2.91 |              5.59 |
# | On昂跑 上海浦东嘉里城     | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海港汇恒隆广场店 | Aspiring Fans        |      1.83 |      1.98 |      3.24 |              7.05 |
# | On昂跑 上海港汇恒隆广场店 | Fans                 |      2.17 |      3.32 |      3.94 |              9.43 |
# | On昂跑 上海港汇恒隆广场店 | High Value           |      3.62 |      3.89 |      3.99 |             11.51 |
# | On昂跑 上海港汇恒隆广场店 | Lost                 |      1    |      2    |      4    |              7    |
# | On昂跑 上海港汇恒隆广场店 | Low Value            |      1.16 |      1.02 |      2.25 |              4.43 |
# | On昂跑 上海港汇恒隆广场店 | Newcomers            |      4    |      1.06 |      1.94 |              7    |
# | On昂跑 上海港汇恒隆广场店 | Passive              |      1    |      1.51 |      2.77 |              5.28 |
# | On昂跑 上海港汇恒隆广场店 | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海环贸iapm       | Aspiring Fans        |      2.13 |      1.8  |      3.03 |              6.96 |
# | On昂跑 上海环贸iapm       | Fans                 |      2.43 |      3.18 |      3.85 |              9.45 |
# | On昂跑 上海环贸iapm       | High Value           |      3.6  |      3.87 |      3.99 |             11.46 |
# | On昂跑 上海环贸iapm       | Lost                 |      1    |      2    |      3    |              6    |
# | On昂跑 上海环贸iapm       | Low Value            |      1.18 |      1.03 |      2.21 |              4.42 |
# | On昂跑 上海环贸iapm       | Newcomers            |      4    |      1.05 |      1.93 |              6.98 |
# | On昂跑 上海环贸iapm       | Passive              |      1    |      1.48 |      2.69 |              5.18 |
# | On昂跑 上海环贸iapm       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海西岸梦中心     | Aspiring Fans        |      2.75 |      1.38 |      2.68 |              6.81 |
# | On昂跑 上海西岸梦中心     | Fans                 |      3.2  |      2.59 |      3.75 |              9.54 |
# | On昂跑 上海西岸梦中心     | High Value           |      3.65 |      3.79 |      3.98 |             11.42 |
# | On昂跑 上海西岸梦中心     | Lost                 |      1    |      1    |      3    |              5    |
# | On昂跑 上海西岸梦中心     | Low Value            |      1.82 |      1.02 |      1.96 |              4.8  |
# | On昂跑 上海西岸梦中心     | Newcomers            |      4    |      1.03 |      1.95 |              6.98 |
# | On昂跑 上海西岸梦中心     | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 上海静安嘉里       | Aspiring Fans        |      2.2  |      1.74 |      2.95 |              6.89 |
# | On昂跑 上海静安嘉里       | Fans                 |      2.41 |      3.15 |      3.87 |              9.43 |
# | On昂跑 上海静安嘉里       | High Value           |      3.62 |      3.87 |      3.98 |             11.48 |
# | On昂跑 上海静安嘉里       | Lost                 |      1    |      1.5  |      2.75 |              5.25 |
# | On昂跑 上海静安嘉里       | Low Value            |      1.28 |      1.04 |      2.17 |              4.49 |
# | On昂跑 上海静安嘉里       | Newcomers            |      4    |      1.05 |      1.94 |              6.98 |
# | On昂跑 上海静安嘉里       | Passive              |      1    |      1.56 |      2.67 |              5.23 |
# | On昂跑 上海静安嘉里       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 北京APM店          | Aspiring Fans        |      2.41 |      1.66 |      2.85 |              6.91 |
# | On昂跑 北京APM店          | Fans                 |      2.72 |      2.96 |      3.79 |              9.47 |
# | On昂跑 北京APM店          | High Value           |      3.62 |      3.84 |      3.98 |             11.44 |
# | On昂跑 北京APM店          | Low Value            |      1.29 |      1.04 |      2.17 |              4.5  |
# | On昂跑 北京APM店          | Newcomers            |      4    |      1.05 |      1.93 |              6.98 |
# | On昂跑 北京APM店          | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 北京三里屯太古里   | Aspiring Fans        |      2.27 |      1.66 |      2.97 |              6.91 |
# | On昂跑 北京三里屯太古里   | Fans                 |      2.5  |      3.09 |      3.87 |              9.45 |
# | On昂跑 北京三里屯太古里   | High Value           |      3.59 |      3.85 |      3.99 |             11.43 |
# | On昂跑 北京三里屯太古里   | Lost                 |      1    |      2    |      3.5  |              6.5  |
# | On昂跑 北京三里屯太古里   | Low Value            |      1.27 |      1.03 |      2.23 |              4.53 |
# | On昂跑 北京三里屯太古里   | Newcomers            |      4    |      1.03 |      1.94 |              6.97 |
# | On昂跑 北京三里屯太古里   | Passive              |      1    |      1.48 |      2.78 |              5.27 |
# | On昂跑 北京三里屯太古里   | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 北京世纪金源       | Aspiring Fans        |      3.3  |      1.18 |      2.49 |              6.97 |
# | On昂跑 北京世纪金源       | Fans                 |      3.63 |      2.27 |      3.64 |              9.54 |
# | On昂跑 北京世纪金源       | High Value           |      3.82 |      3.72 |      3.97 |             11.51 |
# | On昂跑 北京世纪金源       | Low Value            |      3    |      1    |      1    |              5    |
# | On昂跑 北京世纪金源       | Newcomers            |      4    |      1.08 |      1.9  |              6.98 |
# | On昂跑 北京世纪金源       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 北京合生汇店       | Aspiring Fans        |      2.47 |      1.58 |      2.76 |              6.81 |
# | On昂跑 北京合生汇店       | Fans                 |      2.78 |      2.88 |      3.81 |              9.47 |
# | On昂跑 北京合生汇店       | High Value           |      3.58 |      3.87 |      3.98 |             11.43 |
# | On昂跑 北京合生汇店       | Low Value            |      1.43 |      1.04 |      2.09 |              4.56 |
# | On昂跑 北京合生汇店       | Newcomers            |      4    |      1.05 |      1.94 |              6.99 |
# | On昂跑 北京合生汇店       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 北京国贸店         | Aspiring Fans        |      1.94 |      1.8  |      3.22 |              6.95 |
# | On昂跑 北京国贸店         | Fans                 |      2.27 |      3.22 |      3.91 |              9.4  |
# | On昂跑 北京国贸店         | High Value           |      3.6  |      3.87 |      3.99 |             11.46 |
# | On昂跑 北京国贸店         | Lost                 |      1    |      1    |      2.33 |              4.33 |
# | On昂跑 北京国贸店         | Low Value            |      1.19 |      1.03 |      2.23 |              4.44 |
# | On昂跑 北京国贸店         | Newcomers            |      4    |      1.05 |      1.93 |              6.98 |
# | On昂跑 北京国贸店         | Passive              |      1    |      1.56 |      2.71 |              5.27 |
# | On昂跑 北京国贸店         | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 北京荟聚           | Aspiring Fans        |      2.57 |      1.46 |      2.83 |              6.87 |
# | On昂跑 北京荟聚           | Fans                 |      2.91 |      2.77 |      3.82 |              9.5  |
# | On昂跑 北京荟聚           | High Value           |      3.61 |      3.83 |      3.99 |             11.42 |
# | On昂跑 北京荟聚           | Low Value            |      1.41 |      1.04 |      2.09 |              4.54 |
# | On昂跑 北京荟聚           | Newcomers            |      4    |      1.06 |      1.94 |              7    |
# | On昂跑 北京荟聚           | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 北京颐堤港店       | Aspiring Fans        |      1.98 |      1.88 |      3.11 |              6.97 |
# | On昂跑 北京颐堤港店       | Fans                 |      2.33 |      3.22 |      3.88 |              9.43 |
# | On昂跑 北京颐堤港店       | High Value           |      3.57 |      3.86 |      4    |             11.43 |
# | On昂跑 北京颐堤港店       | Lost                 |      1    |      2    |      4    |              7    |
# | On昂跑 北京颐堤港店       | Low Value            |      1.21 |      1.03 |      2.19 |              4.43 |
# | On昂跑 北京颐堤港店       | Newcomers            |      4    |      1.06 |      1.94 |              7    |
# | On昂跑 北京颐堤港店       | Passive              |      1    |      1.57 |      2.7  |              5.27 |
# | On昂跑 北京颐堤港店       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 南京万象天地       | Aspiring Fans        |      2.67 |      1.47 |      2.74 |              6.89 |
# | On昂跑 南京万象天地       | Fans                 |      3.02 |      2.72 |      3.78 |              9.52 |
# | On昂跑 南京万象天地       | High Value           |      3.62 |      3.85 |      3.98 |             11.44 |
# | On昂跑 南京万象天地       | Low Value            |      1.85 |      1.03 |      1.93 |              4.81 |
# | On昂跑 南京万象天地       | Newcomers            |      4    |      1.07 |      1.93 |              7    |
# | On昂跑 南京万象天地       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 天津佛罗伦萨       | Aspiring Fans        |      2.49 |      1.59 |      2.76 |              6.84 |
# | On昂跑 天津佛罗伦萨       | Fans                 |      2.7  |      3    |      3.83 |              9.52 |
# | On昂跑 天津佛罗伦萨       | High Value           |      3.65 |      3.77 |      3.99 |             11.4  |
# | On昂跑 天津佛罗伦萨       | Low Value            |      1.91 |      1.04 |      1.91 |              4.86 |
# | On昂跑 天津佛罗伦萨       | Newcomers            |      4    |      1.08 |      1.92 |              7    |
# | On昂跑 天津佛罗伦萨       | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 广州IGC店          | Aspiring Fans        |      2.8  |      1.43 |      2.7  |              6.93 |
# | On昂跑 广州IGC店          | Fans                 |      3.16 |      2.63 |      3.75 |              9.54 |
# | On昂跑 广州IGC店          | High Value           |      3.67 |      3.8  |      3.97 |             11.45 |
# | On昂跑 广州IGC店          | Low Value            |      2.08 |      1.01 |      1.86 |              4.95 |
# | On昂跑 广州IGC店          | Newcomers            |      4    |      1.06 |      1.9  |              6.96 |
# | On昂跑 广州IGC店          | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 广州太古汇         | Aspiring Fans        |      2.36 |      1.63 |      3    |              6.99 |
# | On昂跑 广州太古汇         | Fans                 |      2.64 |      3.03 |      3.85 |              9.51 |
# | On昂跑 广州太古汇         | High Value           |      3.58 |      3.88 |      3.99 |             11.45 |
# | On昂跑 广州太古汇         | Low Value            |      1.39 |      1.03 |      2.16 |              4.58 |
# | On昂跑 广州太古汇         | Newcomers            |      4    |      1.04 |      1.94 |              6.97 |
# | On昂跑 广州太古汇         | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 成都IFS店          | Aspiring Fans        |      2.24 |      1.63 |      3    |              6.87 |
# | On昂跑 成都IFS店          | Fans                 |      2.58 |      3    |      3.89 |              9.47 |
# | On昂跑 成都IFS店          | High Value           |      3.59 |      3.84 |      4    |             11.43 |
# | On昂跑 成都IFS店          | Lost                 |      1    |      1    |      3    |              5    |
# | On昂跑 成都IFS店          | Low Value            |      1.3  |      1.03 |      2.18 |              4.51 |
# | On昂跑 成都IFS店          | Newcomers            |      4    |      1.03 |      1.99 |              7.02 |
# | On昂跑 成都IFS店          | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 成都仁和新城店     | Aspiring Fans        |      2.15 |      1.74 |      3.06 |              6.94 |
# | On昂跑 成都仁和新城店     | Fans                 |      2.46 |      3.14 |      3.88 |              9.48 |
# | On昂跑 成都仁和新城店     | High Value           |      3.62 |      3.88 |      3.99 |             11.49 |
# | On昂跑 成都仁和新城店     | Low Value            |      1.29 |      1.02 |      2.17 |              4.48 |
# | On昂跑 成都仁和新城店     | Newcomers            |      4    |      1.04 |      1.95 |              6.99 |
# | On昂跑 成都仁和新城店     | Passive              |      1    |      1.7  |      2.91 |              5.61 |
# | On昂跑 成都仁和新城店     | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 成都佛罗伦萨奥莱店 | Aspiring Fans        |      2.24 |      2    |      2.7  |              6.94 |
# | On昂跑 成都佛罗伦萨奥莱店 | Fans                 |      2.77 |      3.16 |      3.59 |              9.52 |
# | On昂跑 成都佛罗伦萨奥莱店 | High Value           |      3.73 |      3.84 |      3.95 |             11.51 |
# | On昂跑 成都佛罗伦萨奥莱店 | Low Value            |      1.34 |      1.17 |      1.84 |              4.35 |
# | On昂跑 成都佛罗伦萨奥莱店 | Newcomers            |      4    |      1.56 |      1.85 |              7.41 |
# | On昂跑 成都佛罗伦萨奥莱店 | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 成都太古里         | Aspiring Fans        |      2.36 |      1.57 |      3    |              6.94 |
# | On昂跑 成都太古里         | Fans                 |      2.53 |      2.99 |      3.89 |              9.41 |
# | On昂跑 成都太古里         | High Value           |      3.6  |      3.85 |      3.99 |             11.44 |
# | On昂跑 成都太古里         | Lost                 |      1    |      1.67 |      2.78 |              5.44 |
# | On昂跑 成都太古里         | Low Value            |      1.28 |      1.02 |      2.2  |              4.51 |
# | On昂跑 成都太古里         | Newcomers            |      4    |      1.04 |      1.95 |              6.99 |
# | On昂跑 成都太古里         | Passive              |      1    |      1.72 |      2.92 |              5.64 |
# | On昂跑 成都太古里         | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 成都太古里旗舰店   | Aspiring Fans        |      3.16 |      1.26 |      2.43 |              6.84 |
# | On昂跑 成都太古里旗舰店   | Fans                 |      3.6  |      2.6  |      3.23 |              9.43 |
# | On昂跑 成都太古里旗舰店   | High Value           |      3.74 |      3.83 |      3.96 |             11.52 |
# | On昂跑 成都太古里旗舰店   | Low Value            |      3    |      1    |      1    |              5    |
# | On昂跑 成都太古里旗舰店   | Newcomers            |      4    |      1.11 |      1.89 |              7    |
# | On昂跑 成都太古里旗舰店   | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 武汉SKP            | Aspiring Fans        |      2.61 |      1.43 |      2.92 |              6.96 |
# | On昂跑 武汉SKP            | Fans                 |      2.88 |      2.79 |      3.86 |              9.53 |
# | On昂跑 武汉SKP            | High Value           |      3.62 |      3.84 |      3.98 |             11.45 |
# | On昂跑 武汉SKP            | Low Value            |      1.72 |      1.02 |      1.99 |              4.73 |
# | On昂跑 武汉SKP            | Newcomers            |      4    |      1.05 |      1.92 |              6.97 |
# | On昂跑 武汉SKP            | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 深圳万象城一期     | Aspiring Fans        |      1.95 |      1.81 |      3.15 |              6.91 |
# | On昂跑 深圳万象城一期     | Fans                 |      2.23 |      3.27 |      3.93 |              9.44 |
# | On昂跑 深圳万象城一期     | High Value           |      3.62 |      3.87 |      3.99 |             11.48 |
# | On昂跑 深圳万象城一期     | Lost                 |      1    |      1.67 |      3.33 |              6    |
# | On昂跑 深圳万象城一期     | Low Value            |      1.34 |      1.02 |      2.15 |              4.51 |
# | On昂跑 深圳万象城一期     | Newcomers            |      4    |      1.08 |      1.96 |              7.03 |
# | On昂跑 深圳万象城一期     | Passive              |      1    |      1.72 |      2.93 |              5.66 |
# | On昂跑 深圳万象城一期     | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 深圳万象城三期店   | Aspiring Fans        |      2.01 |      1.82 |      3.12 |              6.95 |
# | On昂跑 深圳万象城三期店   | Fans                 |      2.27 |      3.23 |      3.91 |              9.41 |
# | On昂跑 深圳万象城三期店   | High Value           |      3.63 |      3.83 |      3.99 |             11.45 |
# | On昂跑 深圳万象城三期店   | Lost                 |      1    |      1    |      2    |              4    |
# | On昂跑 深圳万象城三期店   | Low Value            |      1.13 |      1.01 |      2.19 |              4.34 |
# | On昂跑 深圳万象城三期店   | Newcomers            |      4    |      1.01 |      1.93 |              6.94 |
# | On昂跑 深圳万象城三期店   | Passive              |      1    |      1.63 |      2.81 |              5.44 |
# | On昂跑 深圳万象城三期店   | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 深圳海岸城         | Aspiring Fans        |      2.08 |      1.82 |      3.06 |              6.96 |
# | On昂跑 深圳海岸城         | Fans                 |      2.36 |      3.18 |      3.88 |              9.43 |
# | On昂跑 深圳海岸城         | High Value           |      3.62 |      3.87 |      3.99 |             11.48 |
# | On昂跑 深圳海岸城         | Lost                 |      1    |      1    |      2    |              4    |
# | On昂跑 深圳海岸城         | Low Value            |      1.26 |      1.03 |      2.14 |              4.43 |
# | On昂跑 深圳海岸城         | Newcomers            |      4    |      1.05 |      1.95 |              7    |
# | On昂跑 深圳海岸城         | Passive              |      1    |      1.53 |      2.71 |              5.24 |
# | On昂跑 深圳海岸城         | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | On昂跑 深圳湾万象城       | Aspiring Fans        |      4    |      1    |      3    |              8    |
# | On昂跑 深圳湾万象城       | Fans                 |      4    |      2    |      3.67 |              9.67 |
# | On昂跑 深圳湾万象城       | High Value           |      4    |      3.67 |      4    |             11.67 |
# | On昂跑 深圳湾万象城       | Newcomers            |      4    |      1.25 |      1.75 |              7    |
# | On昂跑 深圳益田假日广场   | Aspiring Fans        |      2.06 |      1.85 |      3.03 |              6.94 |
# | On昂跑 深圳益田假日广场   | Fans                 |      2.22 |      3.32 |      3.89 |              9.44 |
# | On昂跑 深圳益田假日广场   | High Value           |      3.62 |      3.86 |      3.99 |             11.47 |
# | On昂跑 深圳益田假日广场   | Low Value            |      1.3  |      1.02 |      2.14 |              4.47 |
# | On昂跑 深圳益田假日广场   | Newcomers            |      4    |      1.08 |      1.9  |              6.98 |
# | On昂跑 深圳益田假日广场   | Passive              |      1    |      1.62 |      2.87 |              5.49 |
# | On昂跑 深圳益田假日广场   | Zero Value/No Orders |      0    |      0    |      0    |              0    |
# | 微信小店                  | Aspiring Fans        |      3.17 |      1.33 |      1.83 |              6.33 |
# | 微信小店                  | Fans                 |      4    |      1.67 |      3.67 |              9.33 |
# | 微信小店                  | High Value           |      3.67 |      4    |      4    |             11.67 |
# | 微信小店                  | Newcomers            |      4    |      1    |      1.86 |              6.86 |
# | 微信小店                  | Zero Value/No Orders |      0    |      0    |      0    |              0    |

# %%
cluster_channel_counts.to_excel(
    'store_by_segment.xlsx',           # 1. 文件名 (如果文件不存在，会自动创建)
    sheet_name='Sheet1',          # 2. Sheet 名称
    index=False                   # 3. 默认为 True。设置为 False 则不写入 DataFrame 的索引
)
